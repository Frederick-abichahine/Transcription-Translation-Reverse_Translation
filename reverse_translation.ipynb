# %% [markdown]
# # Reverse Translation
# Frederick Abi Chahine

# %%
#!/usr/bin/env python

#Final version of part 2

#Program Description:
#This progran takes a peptide sequence as a user input and then displays all the mRNA sequences that can be formed 
#from this peptide sequence along with all the %GC of each mRNA from lowest % to highest %. Then, the program finds
#the mRNAs that have a %GC closest to 50% and displays them as the most probable mRNAs
#the program terminates after displaying the execution time.

import re                     #regex will be used to ensure that the user input a proper peptide sequence.
from datetime import datetime #will be used in order to display the run time

def generateAllPossibilities(pointer, matrix, mrna_string, possibilities_list):
    #This function is here in order to generate every possible unique mrna sequence from the combination of
    #the codons from the matrix created in function reverseTranscribe. It respects the order of the matrix,
    #in order to generate the appropriate mRNAs for the given peptide sequence.
    
    if pointer==len(matrix):
        possibilities_list.append(mrna_string)
    
    else:
        for codon in matrix[pointer]:
            new_pointer= pointer + 1
            new_mrna_string= mrna_string + codon
            generateAllPossibilities(new_pointer, matrix, new_mrna_string, possibilities_list)
    
    return possibilities_list

def reverseTranscribe(pro_seq):
    #This function takes the protein sequence that the user input as an argument and then generates a matrix in
    #which the mother list has sub-lists, and every sub-list has all possible codons for a specific amino acid.
    #It then computes the # of appropriate mrna sequences that can be generated from this sequence, and then 
    #returns the generated matrix.
    
    codon_map = {"UUU":"F", "UUC":"F", "UUA":"L", "UUG":"L",
                 "UCU":"S", "UCC":"S", "UCA":"S", "UCG":"S",          # UCC is lower case 's'. Values may differ if changed to upper case 'S'
                 "UAU":"Y", "UAC":"Y", "UAA":"STOP", "UAG":"STOP",
                 "UGU":"C", "UGC":"C", "UGA":"STOP", "UGG":"W",
                 "CUU":"L", "CUC":"L", "CUA":"L", "CUG":"L",
                 "CCU":"P", "CCC":"P", "CCA":"P", "CCG":"P",
                 "CAU":"H", "CAC":"H", "CAA":"Q", "CAG":"Q",
                 "CGU":"R", "CGC":"R", "CGA":"R", "CGG":"R",
                 "AUU":"I", "AUC":"I", "AUA":"I", "AUG":"M",
                 "ACU":"T", "ACC":"T", "ACA":"T", "ACG":"T",
                 "AAU":"N", "AAC":"N", "AAA":"K", "AAG":"K",
                 "AGU":"S", "AGC":"S", "AGA":"R", "AGG":"R",
                 "GUU":"V", "GUC":"V", "GUA":"V", "GUG":"V",
                 "GCU":"A", "GCC":"A", "GCA":"A", "GCG":"A",
                 "GAU":"D", "GAC":"D", "GAA":"E", "GAG":"E",
                 "GGU":"G", "GGC":"G", "GGA":"G", "GGG":"G"}
    
    matrix= []
    
    for i in range(len(pro_seq)):
        matrix.append([key for key,val in codon_map.items() if val == pro_seq[i]])
    
    return matrix #every sub-list has all codons for a specific amino acid

def computePercentGC(all_mrnas):
    #This method take the previously created list that has all the mRNA sequences in it, and creates a new list that
    #stores all the %GC for each mRNA respectively (same indices). Then, with the help of zip() we are able to sort 
    #the %GC list and in turn shadow sort the mRNA list with respect to the indices => every mRNA will be at the 
    #same index of its %GC. We need to sort in order to display the mRNAs with their %GC from lowest to highest.
    #Finally, we return both of the lists to later on display them on the screen for the user.
    
    percent_GC= [] #this list will store all the %GC of every mRNA
    for mrna in all_mrnas: 
        #loops through the mRNA list and calculates the %GC for each mRNA to store it in percent_GC
        gc_per= round(((mrna.count('G')+mrna.count('C'))/len(mrna))*100, 2)
        percent_GC.append(gc_per)
    
    #print(percent_GC)
    #print(all_mrnas)
    
    zipped_lists = zip(percent_GC, all_mrnas)  #first is what it sorts (the %) second goes with it (the mRNA)
    sorted_pairs = sorted(zipped_lists)        #shadow sorting the mRNA while sorting the %GC
    tuples = zip(*sorted_pairs)
    percent_GC, all_mrnas = [ list(tuple) for tuple in  tuples]
    
    return all_mrnas, percent_GC
    
def main():
    
    pro_seq= input("Enter protein sequence: ") #ACDEFGHIKLMNPQRSTVWY   ONLYYYY

    while re.findall(r'[^AC-IK-NP-TVWY]', pro_seq): #To ensure that the user enters any correct combination of amino acids, and avoids any typos/wrong letters/wrong case of letters
        print("\n**You entered an invalid letter/character in your sequence. Only input \"ACDEFGHIKLMNPQRSTVWYs\".**\n")
        pro_seq= input("Enter protein sequence:")
    
    start=datetime.now()                                     #this stores the current time in order to subtract it from the time at the end of execution => we get run time
    matrix = reverseTranscribe(pro_seq)                      #invokes the method in order to create the 2D list
    all_mrnas= generateAllPossibilities(0, matrix, "", [])   #invokes the recursive method to generate all combinations of mRNA
    all_mrnas, percent_GC = computePercentGC(all_mrnas)      #invokes the method that computes and sorts the mrnas with their respective %GC
    print()                                                  #to improve display
    
    for i in range(len(percent_GC)):                         #this loop simply displays the content to the screen
        print(all_mrnas[i], ": %GC =", percent_GC[i])
    
    print("\n---> All possible combinations:", len(all_mrnas), "\n")  #displays the number of mRNA combinations
    print("---> The most probable mRNA sequence(s) is/are: (The ones with %GC closest to 50%)\n")
                
    index_array= []                                    #this array will store all the indices of the mRNAs with %GC closest to 50 (or 50 itself)
    result= abs(percent_GC[0]-50)                      #this will be an initializer for the if condition inside the loop (we get absolute value since we do not want the sign to affect our code)
    for i in range(len(percent_GC)):
        if abs(percent_GC[i]-50) < result:             #the percent - 50 will give us the number it is away from 50, so if the number is smaller, it means that it is closer to 50, if it is 0 then it is 50
            result= abs(percent_GC[i]-50)
            index_array= []                            #we have to refresh the index array if it enters this statement in order to remove all previous indices that were assumed closest to 50
            index_array.append(i)
        elif abs(percent_GC[i]-50) == result:          #else if the distance is equal to the smallest then we simply append it to the array to display later on
            index_array.append(i)
            
    for index in index_array:                          #this loop simply displays onto the screen all the mRNA sequences with %GC closest to 50 (or 50 itself)
        print(all_mrnas[index], ": %GC =", percent_GC[index])
    
    print('\n( Run Time: ', datetime.now()-start, ")") #this displays the execution time of this code

main()
# Out:
# Enter protein sequence: sATTS
#
# **You entered an invalid letter/character in your sequence. Only input "ACDEFGHIKLMNPQRSTVWYs".**
#
# Enter protein sequence:SATTS
#
# AGUGCAACAACAAGU : %GC = 40.0
# AGUGCAACAACAUCA : %GC = 40.0
# AGUGCAACAACAUCU : %GC = 40.0
# AGUGCAACAACUAGU : %GC = 40.0
# AGUGCAACAACUUCA : %GC = 40.0
# AGUGCAACAACUUCU : %GC = 40.0
# AGUGCAACUACAAGU : %GC = 40.0
# AGUGCAACUACAUCA : %GC = 40.0
# AGUGCAACUACAUCU : %GC = 40.0
# AGUGCAACUACUAGU : %GC = 40.0
# AGUGCAACUACUUCA : %GC = 40.0
# AGUGCAACUACUUCU : %GC = 40.0
# AGUGCUACAACAAGU : %GC = 40.0
# AGUGCUACAACAUCA : %GC = 40.0
# AGUGCUACAACAUCU : %GC = 40.0
# AGUGCUACAACUAGU : %GC = 40.0
# AGUGCUACAACUUCA : %GC = 40.0
# AGUGCUACAACUUCU : %GC = 40.0
# AGUGCUACUACAAGU : %GC = 40.0
# AGUGCUACUACAUCA : %GC = 40.0
# AGUGCUACUACAUCU : %GC = 40.0
# AGUGCUACUACUAGU : %GC = 40.0
# AGUGCUACUACUUCA : %GC = 40.0
# AGUGCUACUACUUCU : %GC = 40.0
# UCAGCAACAACAAGU : %GC = 40.0
# UCAGCAACAACAUCA : %GC = 40.0
# UCAGCAACAACAUCU : %GC = 40.0
# UCAGCAACAACUAGU : %GC = 40.0
# UCAGCAACAACUUCA : %GC = 40.0
# UCAGCAACAACUUCU : %GC = 40.0
# UCAGCAACUACAAGU : %GC = 40.0
# UCAGCAACUACAUCA : %GC = 40.0
# UCAGCAACUACAUCU : %GC = 40.0
# UCAGCAACUACUAGU : %GC = 40.0
# UCAGCAACUACUUCA : %GC = 40.0
# UCAGCAACUACUUCU : %GC = 40.0
# UCAGCUACAACAAGU : %GC = 40.0
# UCAGCUACAACAUCA : %GC = 40.0
# UCAGCUACAACAUCU : %GC = 40.0
# UCAGCUACAACUAGU : %GC = 40.0
# UCAGCUACAACUUCA : %GC = 40.0
# UCAGCUACAACUUCU : %GC = 40.0
# UCAGCUACUACAAGU : %GC = 40.0
# UCAGCUACUACAUCA : %GC = 40.0
# UCAGCUACUACAUCU : %GC = 40.0
# UCAGCUACUACUAGU : %GC = 40.0
# UCAGCUACUACUUCA : %GC = 40.0
# UCAGCUACUACUUCU : %GC = 40.0
# UCUGCAACAACAAGU : %GC = 40.0
# UCUGCAACAACAUCA : %GC = 40.0
# UCUGCAACAACAUCU : %GC = 40.0
# UCUGCAACAACUAGU : %GC = 40.0
# UCUGCAACAACUUCA : %GC = 40.0
# UCUGCAACAACUUCU : %GC = 40.0
# UCUGCAACUACAAGU : %GC = 40.0
# UCUGCAACUACAUCA : %GC = 40.0
# UCUGCAACUACAUCU : %GC = 40.0
# UCUGCAACUACUAGU : %GC = 40.0
# UCUGCAACUACUUCA : %GC = 40.0
# UCUGCAACUACUUCU : %GC = 40.0
# UCUGCUACAACAAGU : %GC = 40.0
# UCUGCUACAACAUCA : %GC = 40.0
# UCUGCUACAACAUCU : %GC = 40.0
# UCUGCUACAACUAGU : %GC = 40.0
# UCUGCUACAACUUCA : %GC = 40.0
# UCUGCUACAACUUCU : %GC = 40.0
# UCUGCUACUACAAGU : %GC = 40.0
# UCUGCUACUACAUCA : %GC = 40.0
# UCUGCUACUACAUCU : %GC = 40.0
# UCUGCUACUACUAGU : %GC = 40.0
# UCUGCUACUACUUCA : %GC = 40.0
# UCUGCUACUACUUCU : %GC = 40.0
# AGCGCAACAACAAGU : %GC = 46.67
# AGCGCAACAACAUCA : %GC = 46.67
# AGCGCAACAACAUCU : %GC = 46.67
# AGCGCAACAACUAGU : %GC = 46.67
# AGCGCAACAACUUCA : %GC = 46.67
# AGCGCAACAACUUCU : %GC = 46.67
# AGCGCAACUACAAGU : %GC = 46.67
# AGCGCAACUACAUCA : %GC = 46.67
# AGCGCAACUACAUCU : %GC = 46.67
# AGCGCAACUACUAGU : %GC = 46.67
# AGCGCAACUACUUCA : %GC = 46.67
# AGCGCAACUACUUCU : %GC = 46.67
# AGCGCUACAACAAGU : %GC = 46.67
# AGCGCUACAACAUCA : %GC = 46.67
# AGCGCUACAACAUCU : %GC = 46.67
# AGCGCUACAACUAGU : %GC = 46.67
# AGCGCUACAACUUCA : %GC = 46.67
# AGCGCUACAACUUCU : %GC = 46.67
# AGCGCUACUACAAGU : %GC = 46.67
# AGCGCUACUACAUCA : %GC = 46.67
# AGCGCUACUACAUCU : %GC = 46.67
# AGCGCUACUACUAGU : %GC = 46.67
# AGCGCUACUACUUCA : %GC = 46.67
# AGCGCUACUACUUCU : %GC = 46.67
# AGUGCAACAACAAGC : %GC = 46.67
# AGUGCAACAACAUCC : %GC = 46.67
# AGUGCAACAACAUCG : %GC = 46.67
# AGUGCAACAACCAGU : %GC = 46.67
# AGUGCAACAACCUCA : %GC = 46.67
# AGUGCAACAACCUCU : %GC = 46.67
# AGUGCAACAACGAGU : %GC = 46.67
# AGUGCAACAACGUCA : %GC = 46.67
# AGUGCAACAACGUCU : %GC = 46.67
# AGUGCAACAACUAGC : %GC = 46.67
# AGUGCAACAACUUCC : %GC = 46.67
# AGUGCAACAACUUCG : %GC = 46.67
# AGUGCAACCACAAGU : %GC = 46.67
# AGUGCAACCACAUCA : %GC = 46.67
# AGUGCAACCACAUCU : %GC = 46.67
# AGUGCAACCACUAGU : %GC = 46.67
# AGUGCAACCACUUCA : %GC = 46.67
# AGUGCAACCACUUCU : %GC = 46.67
# AGUGCAACGACAAGU : %GC = 46.67
# AGUGCAACGACAUCA : %GC = 46.67
# AGUGCAACGACAUCU : %GC = 46.67
# AGUGCAACGACUAGU : %GC = 46.67
# AGUGCAACGACUUCA : %GC = 46.67
# AGUGCAACGACUUCU : %GC = 46.67
# AGUGCAACUACAAGC : %GC = 46.67
# AGUGCAACUACAUCC : %GC = 46.67
# AGUGCAACUACAUCG : %GC = 46.67
# AGUGCAACUACCAGU : %GC = 46.67
# AGUGCAACUACCUCA : %GC = 46.67
# AGUGCAACUACCUCU : %GC = 46.67
# AGUGCAACUACGAGU : %GC = 46.67
# AGUGCAACUACGUCA : %GC = 46.67
# AGUGCAACUACGUCU : %GC = 46.67
# AGUGCAACUACUAGC : %GC = 46.67
# AGUGCAACUACUUCC : %GC = 46.67
# AGUGCAACUACUUCG : %GC = 46.67
# AGUGCCACAACAAGU : %GC = 46.67
# AGUGCCACAACAUCA : %GC = 46.67
# AGUGCCACAACAUCU : %GC = 46.67
# AGUGCCACAACUAGU : %GC = 46.67
# AGUGCCACAACUUCA : %GC = 46.67
# AGUGCCACAACUUCU : %GC = 46.67
# AGUGCCACUACAAGU : %GC = 46.67
# AGUGCCACUACAUCA : %GC = 46.67
# AGUGCCACUACAUCU : %GC = 46.67
# AGUGCCACUACUAGU : %GC = 46.67
# AGUGCCACUACUUCA : %GC = 46.67
# AGUGCCACUACUUCU : %GC = 46.67
# AGUGCGACAACAAGU : %GC = 46.67
# AGUGCGACAACAUCA : %GC = 46.67
# AGUGCGACAACAUCU : %GC = 46.67
# AGUGCGACAACUAGU : %GC = 46.67
# AGUGCGACAACUUCA : %GC = 46.67
# AGUGCGACAACUUCU : %GC = 46.67
# AGUGCGACUACAAGU : %GC = 46.67
# AGUGCGACUACAUCA : %GC = 46.67
# AGUGCGACUACAUCU : %GC = 46.67
# AGUGCGACUACUAGU : %GC = 46.67
# AGUGCGACUACUUCA : %GC = 46.67
# AGUGCGACUACUUCU : %GC = 46.67
# AGUGCUACAACAAGC : %GC = 46.67
# AGUGCUACAACAUCC : %GC = 46.67
# AGUGCUACAACAUCG : %GC = 46.67
# AGUGCUACAACCAGU : %GC = 46.67
# AGUGCUACAACCUCA : %GC = 46.67
# AGUGCUACAACCUCU : %GC = 46.67
# AGUGCUACAACGAGU : %GC = 46.67
# AGUGCUACAACGUCA : %GC = 46.67
# AGUGCUACAACGUCU : %GC = 46.67
# AGUGCUACAACUAGC : %GC = 46.67
# AGUGCUACAACUUCC : %GC = 46.67
# AGUGCUACAACUUCG : %GC = 46.67
# AGUGCUACCACAAGU : %GC = 46.67
# AGUGCUACCACAUCA : %GC = 46.67
# AGUGCUACCACAUCU : %GC = 46.67
# AGUGCUACCACUAGU : %GC = 46.67
# AGUGCUACCACUUCA : %GC = 46.67
# AGUGCUACCACUUCU : %GC = 46.67
# AGUGCUACGACAAGU : %GC = 46.67
# AGUGCUACGACAUCA : %GC = 46.67
# AGUGCUACGACAUCU : %GC = 46.67
# AGUGCUACGACUAGU : %GC = 46.67
# AGUGCUACGACUUCA : %GC = 46.67
# AGUGCUACGACUUCU : %GC = 46.67
# AGUGCUACUACAAGC : %GC = 46.67
# AGUGCUACUACAUCC : %GC = 46.67
# AGUGCUACUACAUCG : %GC = 46.67
# AGUGCUACUACCAGU : %GC = 46.67
# AGUGCUACUACCUCA : %GC = 46.67
# AGUGCUACUACCUCU : %GC = 46.67
# AGUGCUACUACGAGU : %GC = 46.67
# AGUGCUACUACGUCA : %GC = 46.67
# AGUGCUACUACGUCU : %GC = 46.67
# AGUGCUACUACUAGC : %GC = 46.67
# AGUGCUACUACUUCC : %GC = 46.67
# AGUGCUACUACUUCG : %GC = 46.67
# UCAGCAACAACAAGC : %GC = 46.67
# UCAGCAACAACAUCC : %GC = 46.67
# UCAGCAACAACAUCG : %GC = 46.67
# UCAGCAACAACCAGU : %GC = 46.67
# UCAGCAACAACCUCA : %GC = 46.67
# UCAGCAACAACCUCU : %GC = 46.67
# UCAGCAACAACGAGU : %GC = 46.67
# UCAGCAACAACGUCA : %GC = 46.67
# UCAGCAACAACGUCU : %GC = 46.67
# UCAGCAACAACUAGC : %GC = 46.67
# UCAGCAACAACUUCC : %GC = 46.67
# UCAGCAACAACUUCG : %GC = 46.67
# UCAGCAACCACAAGU : %GC = 46.67
# UCAGCAACCACAUCA : %GC = 46.67
# UCAGCAACCACAUCU : %GC = 46.67
# UCAGCAACCACUAGU : %GC = 46.67
# UCAGCAACCACUUCA : %GC = 46.67
# UCAGCAACCACUUCU : %GC = 46.67
# UCAGCAACGACAAGU : %GC = 46.67
# UCAGCAACGACAUCA : %GC = 46.67
# UCAGCAACGACAUCU : %GC = 46.67
# UCAGCAACGACUAGU : %GC = 46.67
# UCAGCAACGACUUCA : %GC = 46.67
# UCAGCAACGACUUCU : %GC = 46.67
# UCAGCAACUACAAGC : %GC = 46.67
# UCAGCAACUACAUCC : %GC = 46.67
# UCAGCAACUACAUCG : %GC = 46.67
# UCAGCAACUACCAGU : %GC = 46.67
# UCAGCAACUACCUCA : %GC = 46.67
# UCAGCAACUACCUCU : %GC = 46.67
# UCAGCAACUACGAGU : %GC = 46.67
# UCAGCAACUACGUCA : %GC = 46.67
# UCAGCAACUACGUCU : %GC = 46.67
# UCAGCAACUACUAGC : %GC = 46.67
# UCAGCAACUACUUCC : %GC = 46.67
# UCAGCAACUACUUCG : %GC = 46.67
# UCAGCCACAACAAGU : %GC = 46.67
# UCAGCCACAACAUCA : %GC = 46.67
# UCAGCCACAACAUCU : %GC = 46.67
# UCAGCCACAACUAGU : %GC = 46.67
# UCAGCCACAACUUCA : %GC = 46.67
# UCAGCCACAACUUCU : %GC = 46.67
# UCAGCCACUACAAGU : %GC = 46.67
# UCAGCCACUACAUCA : %GC = 46.67
# UCAGCCACUACAUCU : %GC = 46.67
# UCAGCCACUACUAGU : %GC = 46.67
# UCAGCCACUACUUCA : %GC = 46.67
# UCAGCCACUACUUCU : %GC = 46.67
# UCAGCGACAACAAGU : %GC = 46.67
# UCAGCGACAACAUCA : %GC = 46.67
# UCAGCGACAACAUCU : %GC = 46.67
# UCAGCGACAACUAGU : %GC = 46.67
# UCAGCGACAACUUCA : %GC = 46.67
# UCAGCGACAACUUCU : %GC = 46.67
# UCAGCGACUACAAGU : %GC = 46.67
# UCAGCGACUACAUCA : %GC = 46.67
# UCAGCGACUACAUCU : %GC = 46.67
# UCAGCGACUACUAGU : %GC = 46.67
# UCAGCGACUACUUCA : %GC = 46.67
# UCAGCGACUACUUCU : %GC = 46.67
# UCAGCUACAACAAGC : %GC = 46.67
# UCAGCUACAACAUCC : %GC = 46.67
# UCAGCUACAACAUCG : %GC = 46.67
# UCAGCUACAACCAGU : %GC = 46.67
# UCAGCUACAACCUCA : %GC = 46.67
# UCAGCUACAACCUCU : %GC = 46.67
# UCAGCUACAACGAGU : %GC = 46.67
# UCAGCUACAACGUCA : %GC = 46.67
# UCAGCUACAACGUCU : %GC = 46.67
# UCAGCUACAACUAGC : %GC = 46.67
# UCAGCUACAACUUCC : %GC = 46.67
# UCAGCUACAACUUCG : %GC = 46.67
# UCAGCUACCACAAGU : %GC = 46.67
# UCAGCUACCACAUCA : %GC = 46.67
# UCAGCUACCACAUCU : %GC = 46.67
# UCAGCUACCACUAGU : %GC = 46.67
# UCAGCUACCACUUCA : %GC = 46.67
# UCAGCUACCACUUCU : %GC = 46.67
# UCAGCUACGACAAGU : %GC = 46.67
# UCAGCUACGACAUCA : %GC = 46.67
# UCAGCUACGACAUCU : %GC = 46.67
# UCAGCUACGACUAGU : %GC = 46.67
# UCAGCUACGACUUCA : %GC = 46.67
# UCAGCUACGACUUCU : %GC = 46.67
# UCAGCUACUACAAGC : %GC = 46.67
# UCAGCUACUACAUCC : %GC = 46.67
# UCAGCUACUACAUCG : %GC = 46.67
# UCAGCUACUACCAGU : %GC = 46.67
# UCAGCUACUACCUCA : %GC = 46.67
# UCAGCUACUACCUCU : %GC = 46.67
# UCAGCUACUACGAGU : %GC = 46.67
# UCAGCUACUACGUCA : %GC = 46.67
# UCAGCUACUACGUCU : %GC = 46.67
# UCAGCUACUACUAGC : %GC = 46.67
# UCAGCUACUACUUCC : %GC = 46.67
# UCAGCUACUACUUCG : %GC = 46.67
# UCCGCAACAACAAGU : %GC = 46.67
# UCCGCAACAACAUCA : %GC = 46.67
# UCCGCAACAACAUCU : %GC = 46.67
# UCCGCAACAACUAGU : %GC = 46.67
# UCCGCAACAACUUCA : %GC = 46.67
# UCCGCAACAACUUCU : %GC = 46.67
# UCCGCAACUACAAGU : %GC = 46.67
# UCCGCAACUACAUCA : %GC = 46.67
# UCCGCAACUACAUCU : %GC = 46.67
# UCCGCAACUACUAGU : %GC = 46.67
# UCCGCAACUACUUCA : %GC = 46.67
# UCCGCAACUACUUCU : %GC = 46.67
# UCCGCUACAACAAGU : %GC = 46.67
# UCCGCUACAACAUCA : %GC = 46.67
# UCCGCUACAACAUCU : %GC = 46.67
# UCCGCUACAACUAGU : %GC = 46.67
# UCCGCUACAACUUCA : %GC = 46.67
# UCCGCUACAACUUCU : %GC = 46.67
# UCCGCUACUACAAGU : %GC = 46.67
# UCCGCUACUACAUCA : %GC = 46.67
# UCCGCUACUACAUCU : %GC = 46.67
# UCCGCUACUACUAGU : %GC = 46.67
# UCCGCUACUACUUCA : %GC = 46.67
# UCCGCUACUACUUCU : %GC = 46.67
# UCGGCAACAACAAGU : %GC = 46.67
# UCGGCAACAACAUCA : %GC = 46.67
# UCGGCAACAACAUCU : %GC = 46.67
# UCGGCAACAACUAGU : %GC = 46.67
# UCGGCAACAACUUCA : %GC = 46.67
# UCGGCAACAACUUCU : %GC = 46.67
# UCGGCAACUACAAGU : %GC = 46.67
# UCGGCAACUACAUCA : %GC = 46.67
# UCGGCAACUACAUCU : %GC = 46.67
# UCGGCAACUACUAGU : %GC = 46.67
# UCGGCAACUACUUCA : %GC = 46.67
# UCGGCAACUACUUCU : %GC = 46.67
# UCGGCUACAACAAGU : %GC = 46.67
# UCGGCUACAACAUCA : %GC = 46.67
# UCGGCUACAACAUCU : %GC = 46.67
# UCGGCUACAACUAGU : %GC = 46.67
# UCGGCUACAACUUCA : %GC = 46.67
# UCGGCUACAACUUCU : %GC = 46.67
# UCGGCUACUACAAGU : %GC = 46.67
# UCGGCUACUACAUCA : %GC = 46.67
# UCGGCUACUACAUCU : %GC = 46.67
# UCGGCUACUACUAGU : %GC = 46.67
# UCGGCUACUACUUCA : %GC = 46.67
# UCGGCUACUACUUCU : %GC = 46.67
# UCUGCAACAACAAGC : %GC = 46.67
# UCUGCAACAACAUCC : %GC = 46.67
# UCUGCAACAACAUCG : %GC = 46.67
# UCUGCAACAACCAGU : %GC = 46.67
# UCUGCAACAACCUCA : %GC = 46.67
# UCUGCAACAACCUCU : %GC = 46.67
# UCUGCAACAACGAGU : %GC = 46.67
# UCUGCAACAACGUCA : %GC = 46.67
# UCUGCAACAACGUCU : %GC = 46.67
# UCUGCAACAACUAGC : %GC = 46.67
# UCUGCAACAACUUCC : %GC = 46.67
# UCUGCAACAACUUCG : %GC = 46.67
# UCUGCAACCACAAGU : %GC = 46.67
# UCUGCAACCACAUCA : %GC = 46.67
# UCUGCAACCACAUCU : %GC = 46.67
# UCUGCAACCACUAGU : %GC = 46.67
# UCUGCAACCACUUCA : %GC = 46.67
# UCUGCAACCACUUCU : %GC = 46.67
# UCUGCAACGACAAGU : %GC = 46.67
# UCUGCAACGACAUCA : %GC = 46.67
# UCUGCAACGACAUCU : %GC = 46.67
# UCUGCAACGACUAGU : %GC = 46.67
# UCUGCAACGACUUCA : %GC = 46.67
# UCUGCAACGACUUCU : %GC = 46.67
# UCUGCAACUACAAGC : %GC = 46.67
# UCUGCAACUACAUCC : %GC = 46.67
# UCUGCAACUACAUCG : %GC = 46.67
# UCUGCAACUACCAGU : %GC = 46.67
# UCUGCAACUACCUCA : %GC = 46.67
# UCUGCAACUACCUCU : %GC = 46.67
# UCUGCAACUACGAGU : %GC = 46.67
# UCUGCAACUACGUCA : %GC = 46.67
# UCUGCAACUACGUCU : %GC = 46.67
# UCUGCAACUACUAGC : %GC = 46.67
# UCUGCAACUACUUCC : %GC = 46.67
# UCUGCAACUACUUCG : %GC = 46.67
# UCUGCCACAACAAGU : %GC = 46.67
# UCUGCCACAACAUCA : %GC = 46.67
# UCUGCCACAACAUCU : %GC = 46.67
# UCUGCCACAACUAGU : %GC = 46.67
# UCUGCCACAACUUCA : %GC = 46.67
# UCUGCCACAACUUCU : %GC = 46.67
# UCUGCCACUACAAGU : %GC = 46.67
# UCUGCCACUACAUCA : %GC = 46.67
# UCUGCCACUACAUCU : %GC = 46.67
# UCUGCCACUACUAGU : %GC = 46.67
# UCUGCCACUACUUCA : %GC = 46.67
# UCUGCCACUACUUCU : %GC = 46.67
# UCUGCGACAACAAGU : %GC = 46.67
# UCUGCGACAACAUCA : %GC = 46.67
# UCUGCGACAACAUCU : %GC = 46.67
# UCUGCGACAACUAGU : %GC = 46.67
# UCUGCGACAACUUCA : %GC = 46.67
# UCUGCGACAACUUCU : %GC = 46.67
# UCUGCGACUACAAGU : %GC = 46.67
# UCUGCGACUACAUCA : %GC = 46.67
# UCUGCGACUACAUCU : %GC = 46.67
# UCUGCGACUACUAGU : %GC = 46.67
# UCUGCGACUACUUCA : %GC = 46.67
# UCUGCGACUACUUCU : %GC = 46.67
# UCUGCUACAACAAGC : %GC = 46.67
# UCUGCUACAACAUCC : %GC = 46.67
# UCUGCUACAACAUCG : %GC = 46.67
# UCUGCUACAACCAGU : %GC = 46.67
# UCUGCUACAACCUCA : %GC = 46.67
# UCUGCUACAACCUCU : %GC = 46.67
# UCUGCUACAACGAGU : %GC = 46.67
# UCUGCUACAACGUCA : %GC = 46.67
# UCUGCUACAACGUCU : %GC = 46.67
# UCUGCUACAACUAGC : %GC = 46.67
# UCUGCUACAACUUCC : %GC = 46.67
# UCUGCUACAACUUCG : %GC = 46.67
# UCUGCUACCACAAGU : %GC = 46.67
# UCUGCUACCACAUCA : %GC = 46.67
# UCUGCUACCACAUCU : %GC = 46.67
# UCUGCUACCACUAGU : %GC = 46.67
# UCUGCUACCACUUCA : %GC = 46.67
# UCUGCUACCACUUCU : %GC = 46.67
# UCUGCUACGACAAGU : %GC = 46.67
# UCUGCUACGACAUCA : %GC = 46.67
# UCUGCUACGACAUCU : %GC = 46.67
# UCUGCUACGACUAGU : %GC = 46.67
# UCUGCUACGACUUCA : %GC = 46.67
# UCUGCUACGACUUCU : %GC = 46.67
# UCUGCUACUACAAGC : %GC = 46.67
# UCUGCUACUACAUCC : %GC = 46.67
# UCUGCUACUACAUCG : %GC = 46.67
# UCUGCUACUACCAGU : %GC = 46.67
# UCUGCUACUACCUCA : %GC = 46.67
# UCUGCUACUACCUCU : %GC = 46.67
# UCUGCUACUACGAGU : %GC = 46.67
# UCUGCUACUACGUCA : %GC = 46.67
# UCUGCUACUACGUCU : %GC = 46.67
# UCUGCUACUACUAGC : %GC = 46.67
# UCUGCUACUACUUCC : %GC = 46.67
# UCUGCUACUACUUCG : %GC = 46.67
# AGCGCAACAACAAGC : %GC = 53.33
# AGCGCAACAACAUCC : %GC = 53.33
# AGCGCAACAACAUCG : %GC = 53.33
# AGCGCAACAACCAGU : %GC = 53.33
# AGCGCAACAACCUCA : %GC = 53.33
# AGCGCAACAACCUCU : %GC = 53.33
# AGCGCAACAACGAGU : %GC = 53.33
# AGCGCAACAACGUCA : %GC = 53.33
# AGCGCAACAACGUCU : %GC = 53.33
# AGCGCAACAACUAGC : %GC = 53.33
# AGCGCAACAACUUCC : %GC = 53.33
# AGCGCAACAACUUCG : %GC = 53.33
# AGCGCAACCACAAGU : %GC = 53.33
# AGCGCAACCACAUCA : %GC = 53.33
# AGCGCAACCACAUCU : %GC = 53.33
# AGCGCAACCACUAGU : %GC = 53.33
# AGCGCAACCACUUCA : %GC = 53.33
# AGCGCAACCACUUCU : %GC = 53.33
# AGCGCAACGACAAGU : %GC = 53.33
# AGCGCAACGACAUCA : %GC = 53.33
# AGCGCAACGACAUCU : %GC = 53.33
# AGCGCAACGACUAGU : %GC = 53.33
# AGCGCAACGACUUCA : %GC = 53.33
# AGCGCAACGACUUCU : %GC = 53.33
# AGCGCAACUACAAGC : %GC = 53.33
# AGCGCAACUACAUCC : %GC = 53.33
# AGCGCAACUACAUCG : %GC = 53.33
# AGCGCAACUACCAGU : %GC = 53.33
# AGCGCAACUACCUCA : %GC = 53.33
# AGCGCAACUACCUCU : %GC = 53.33
# AGCGCAACUACGAGU : %GC = 53.33
# AGCGCAACUACGUCA : %GC = 53.33
# AGCGCAACUACGUCU : %GC = 53.33
# AGCGCAACUACUAGC : %GC = 53.33
# AGCGCAACUACUUCC : %GC = 53.33
# AGCGCAACUACUUCG : %GC = 53.33
# AGCGCCACAACAAGU : %GC = 53.33
# AGCGCCACAACAUCA : %GC = 53.33
# AGCGCCACAACAUCU : %GC = 53.33
# AGCGCCACAACUAGU : %GC = 53.33
# AGCGCCACAACUUCA : %GC = 53.33
# AGCGCCACAACUUCU : %GC = 53.33
# AGCGCCACUACAAGU : %GC = 53.33
# AGCGCCACUACAUCA : %GC = 53.33
# AGCGCCACUACAUCU : %GC = 53.33
# AGCGCCACUACUAGU : %GC = 53.33
# AGCGCCACUACUUCA : %GC = 53.33
# AGCGCCACUACUUCU : %GC = 53.33
# AGCGCGACAACAAGU : %GC = 53.33
# AGCGCGACAACAUCA : %GC = 53.33
# AGCGCGACAACAUCU : %GC = 53.33
# AGCGCGACAACUAGU : %GC = 53.33
# AGCGCGACAACUUCA : %GC = 53.33
# AGCGCGACAACUUCU : %GC = 53.33
# AGCGCGACUACAAGU : %GC = 53.33
# AGCGCGACUACAUCA : %GC = 53.33
# AGCGCGACUACAUCU : %GC = 53.33
# AGCGCGACUACUAGU : %GC = 53.33
# AGCGCGACUACUUCA : %GC = 53.33
# AGCGCGACUACUUCU : %GC = 53.33
# AGCGCUACAACAAGC : %GC = 53.33
# AGCGCUACAACAUCC : %GC = 53.33
# AGCGCUACAACAUCG : %GC = 53.33
# AGCGCUACAACCAGU : %GC = 53.33
# AGCGCUACAACCUCA : %GC = 53.33
# AGCGCUACAACCUCU : %GC = 53.33
# AGCGCUACAACGAGU : %GC = 53.33
# AGCGCUACAACGUCA : %GC = 53.33
# AGCGCUACAACGUCU : %GC = 53.33
# AGCGCUACAACUAGC : %GC = 53.33
# AGCGCUACAACUUCC : %GC = 53.33
# AGCGCUACAACUUCG : %GC = 53.33
# AGCGCUACCACAAGU : %GC = 53.33
# AGCGCUACCACAUCA : %GC = 53.33
# AGCGCUACCACAUCU : %GC = 53.33
# AGCGCUACCACUAGU : %GC = 53.33
# AGCGCUACCACUUCA : %GC = 53.33
# AGCGCUACCACUUCU : %GC = 53.33
# AGCGCUACGACAAGU : %GC = 53.33
# AGCGCUACGACAUCA : %GC = 53.33
# AGCGCUACGACAUCU : %GC = 53.33
# AGCGCUACGACUAGU : %GC = 53.33
# AGCGCUACGACUUCA : %GC = 53.33
# AGCGCUACGACUUCU : %GC = 53.33
# AGCGCUACUACAAGC : %GC = 53.33
# AGCGCUACUACAUCC : %GC = 53.33
# AGCGCUACUACAUCG : %GC = 53.33
# AGCGCUACUACCAGU : %GC = 53.33
# AGCGCUACUACCUCA : %GC = 53.33
# AGCGCUACUACCUCU : %GC = 53.33
# AGCGCUACUACGAGU : %GC = 53.33
# AGCGCUACUACGUCA : %GC = 53.33
# AGCGCUACUACGUCU : %GC = 53.33
# AGCGCUACUACUAGC : %GC = 53.33
# AGCGCUACUACUUCC : %GC = 53.33
# AGCGCUACUACUUCG : %GC = 53.33
# AGUGCAACAACCAGC : %GC = 53.33
# AGUGCAACAACCUCC : %GC = 53.33
# AGUGCAACAACCUCG : %GC = 53.33
# AGUGCAACAACGAGC : %GC = 53.33
# AGUGCAACAACGUCC : %GC = 53.33
# AGUGCAACAACGUCG : %GC = 53.33
# AGUGCAACCACAAGC : %GC = 53.33
# AGUGCAACCACAUCC : %GC = 53.33
# AGUGCAACCACAUCG : %GC = 53.33
# AGUGCAACCACCAGU : %GC = 53.33
# AGUGCAACCACCUCA : %GC = 53.33
# AGUGCAACCACCUCU : %GC = 53.33
# AGUGCAACCACGAGU : %GC = 53.33
# AGUGCAACCACGUCA : %GC = 53.33
# AGUGCAACCACGUCU : %GC = 53.33
# AGUGCAACCACUAGC : %GC = 53.33
# AGUGCAACCACUUCC : %GC = 53.33
# AGUGCAACCACUUCG : %GC = 53.33
# AGUGCAACGACAAGC : %GC = 53.33
# AGUGCAACGACAUCC : %GC = 53.33
# AGUGCAACGACAUCG : %GC = 53.33
# AGUGCAACGACCAGU : %GC = 53.33
# AGUGCAACGACCUCA : %GC = 53.33
# AGUGCAACGACCUCU : %GC = 53.33
# AGUGCAACGACGAGU : %GC = 53.33
# AGUGCAACGACGUCA : %GC = 53.33
# AGUGCAACGACGUCU : %GC = 53.33
# AGUGCAACGACUAGC : %GC = 53.33
# AGUGCAACGACUUCC : %GC = 53.33
# AGUGCAACGACUUCG : %GC = 53.33
# AGUGCAACUACCAGC : %GC = 53.33
# AGUGCAACUACCUCC : %GC = 53.33
# AGUGCAACUACCUCG : %GC = 53.33
# AGUGCAACUACGAGC : %GC = 53.33
# AGUGCAACUACGUCC : %GC = 53.33
# AGUGCAACUACGUCG : %GC = 53.33
# AGUGCCACAACAAGC : %GC = 53.33
# AGUGCCACAACAUCC : %GC = 53.33
# AGUGCCACAACAUCG : %GC = 53.33
# AGUGCCACAACCAGU : %GC = 53.33
# AGUGCCACAACCUCA : %GC = 53.33
# AGUGCCACAACCUCU : %GC = 53.33
# AGUGCCACAACGAGU : %GC = 53.33
# AGUGCCACAACGUCA : %GC = 53.33
# AGUGCCACAACGUCU : %GC = 53.33
# AGUGCCACAACUAGC : %GC = 53.33
# AGUGCCACAACUUCC : %GC = 53.33
# AGUGCCACAACUUCG : %GC = 53.33
# AGUGCCACCACAAGU : %GC = 53.33
# AGUGCCACCACAUCA : %GC = 53.33
# AGUGCCACCACAUCU : %GC = 53.33
# AGUGCCACCACUAGU : %GC = 53.33
# AGUGCCACCACUUCA : %GC = 53.33
# AGUGCCACCACUUCU : %GC = 53.33
# AGUGCCACGACAAGU : %GC = 53.33
# AGUGCCACGACAUCA : %GC = 53.33
# AGUGCCACGACAUCU : %GC = 53.33
# AGUGCCACGACUAGU : %GC = 53.33
# AGUGCCACGACUUCA : %GC = 53.33
# AGUGCCACGACUUCU : %GC = 53.33
# AGUGCCACUACAAGC : %GC = 53.33
# AGUGCCACUACAUCC : %GC = 53.33
# AGUGCCACUACAUCG : %GC = 53.33
# AGUGCCACUACCAGU : %GC = 53.33
# AGUGCCACUACCUCA : %GC = 53.33
# AGUGCCACUACCUCU : %GC = 53.33
# AGUGCCACUACGAGU : %GC = 53.33
# AGUGCCACUACGUCA : %GC = 53.33
# AGUGCCACUACGUCU : %GC = 53.33
# AGUGCCACUACUAGC : %GC = 53.33
# AGUGCCACUACUUCC : %GC = 53.33
# AGUGCCACUACUUCG : %GC = 53.33
# AGUGCGACAACAAGC : %GC = 53.33
# AGUGCGACAACAUCC : %GC = 53.33
# AGUGCGACAACAUCG : %GC = 53.33
# AGUGCGACAACCAGU : %GC = 53.33
# AGUGCGACAACCUCA : %GC = 53.33
# AGUGCGACAACCUCU : %GC = 53.33
# AGUGCGACAACGAGU : %GC = 53.33
# AGUGCGACAACGUCA : %GC = 53.33
# AGUGCGACAACGUCU : %GC = 53.33
# AGUGCGACAACUAGC : %GC = 53.33
# AGUGCGACAACUUCC : %GC = 53.33
# AGUGCGACAACUUCG : %GC = 53.33
# AGUGCGACCACAAGU : %GC = 53.33
# AGUGCGACCACAUCA : %GC = 53.33
# AGUGCGACCACAUCU : %GC = 53.33
# AGUGCGACCACUAGU : %GC = 53.33
# AGUGCGACCACUUCA : %GC = 53.33
# AGUGCGACCACUUCU : %GC = 53.33
# AGUGCGACGACAAGU : %GC = 53.33
# AGUGCGACGACAUCA : %GC = 53.33
# AGUGCGACGACAUCU : %GC = 53.33
# AGUGCGACGACUAGU : %GC = 53.33
# AGUGCGACGACUUCA : %GC = 53.33
# AGUGCGACGACUUCU : %GC = 53.33
# AGUGCGACUACAAGC : %GC = 53.33
# AGUGCGACUACAUCC : %GC = 53.33
# AGUGCGACUACAUCG : %GC = 53.33
# AGUGCGACUACCAGU : %GC = 53.33
# AGUGCGACUACCUCA : %GC = 53.33
# AGUGCGACUACCUCU : %GC = 53.33
# AGUGCGACUACGAGU : %GC = 53.33
# AGUGCGACUACGUCA : %GC = 53.33
# AGUGCGACUACGUCU : %GC = 53.33
# AGUGCGACUACUAGC : %GC = 53.33
# AGUGCGACUACUUCC : %GC = 53.33
# AGUGCGACUACUUCG : %GC = 53.33
# AGUGCUACAACCAGC : %GC = 53.33
# AGUGCUACAACCUCC : %GC = 53.33
# AGUGCUACAACCUCG : %GC = 53.33
# AGUGCUACAACGAGC : %GC = 53.33
# AGUGCUACAACGUCC : %GC = 53.33
# AGUGCUACAACGUCG : %GC = 53.33
# AGUGCUACCACAAGC : %GC = 53.33
# AGUGCUACCACAUCC : %GC = 53.33
# AGUGCUACCACAUCG : %GC = 53.33
# AGUGCUACCACCAGU : %GC = 53.33
# AGUGCUACCACCUCA : %GC = 53.33
# AGUGCUACCACCUCU : %GC = 53.33
# AGUGCUACCACGAGU : %GC = 53.33
# AGUGCUACCACGUCA : %GC = 53.33
# AGUGCUACCACGUCU : %GC = 53.33
# AGUGCUACCACUAGC : %GC = 53.33
# AGUGCUACCACUUCC : %GC = 53.33
# AGUGCUACCACUUCG : %GC = 53.33
# AGUGCUACGACAAGC : %GC = 53.33
# AGUGCUACGACAUCC : %GC = 53.33
# AGUGCUACGACAUCG : %GC = 53.33
# AGUGCUACGACCAGU : %GC = 53.33
# AGUGCUACGACCUCA : %GC = 53.33
# AGUGCUACGACCUCU : %GC = 53.33
# AGUGCUACGACGAGU : %GC = 53.33
# AGUGCUACGACGUCA : %GC = 53.33
# AGUGCUACGACGUCU : %GC = 53.33
# AGUGCUACGACUAGC : %GC = 53.33
# AGUGCUACGACUUCC : %GC = 53.33
# AGUGCUACGACUUCG : %GC = 53.33
# AGUGCUACUACCAGC : %GC = 53.33
# AGUGCUACUACCUCC : %GC = 53.33
# AGUGCUACUACCUCG : %GC = 53.33
# AGUGCUACUACGAGC : %GC = 53.33
# AGUGCUACUACGUCC : %GC = 53.33
# AGUGCUACUACGUCG : %GC = 53.33
# UCAGCAACAACCAGC : %GC = 53.33
# UCAGCAACAACCUCC : %GC = 53.33
# UCAGCAACAACCUCG : %GC = 53.33
# UCAGCAACAACGAGC : %GC = 53.33
# UCAGCAACAACGUCC : %GC = 53.33
# UCAGCAACAACGUCG : %GC = 53.33
# UCAGCAACCACAAGC : %GC = 53.33
# UCAGCAACCACAUCC : %GC = 53.33
# UCAGCAACCACAUCG : %GC = 53.33
# UCAGCAACCACCAGU : %GC = 53.33
# UCAGCAACCACCUCA : %GC = 53.33
# UCAGCAACCACCUCU : %GC = 53.33
# UCAGCAACCACGAGU : %GC = 53.33
# UCAGCAACCACGUCA : %GC = 53.33
# UCAGCAACCACGUCU : %GC = 53.33
# UCAGCAACCACUAGC : %GC = 53.33
# UCAGCAACCACUUCC : %GC = 53.33
# UCAGCAACCACUUCG : %GC = 53.33
# UCAGCAACGACAAGC : %GC = 53.33
# UCAGCAACGACAUCC : %GC = 53.33
# UCAGCAACGACAUCG : %GC = 53.33
# UCAGCAACGACCAGU : %GC = 53.33
# UCAGCAACGACCUCA : %GC = 53.33
# UCAGCAACGACCUCU : %GC = 53.33
# UCAGCAACGACGAGU : %GC = 53.33
# UCAGCAACGACGUCA : %GC = 53.33
# UCAGCAACGACGUCU : %GC = 53.33
# UCAGCAACGACUAGC : %GC = 53.33
# UCAGCAACGACUUCC : %GC = 53.33
# UCAGCAACGACUUCG : %GC = 53.33
# UCAGCAACUACCAGC : %GC = 53.33
# UCAGCAACUACCUCC : %GC = 53.33
# UCAGCAACUACCUCG : %GC = 53.33
# UCAGCAACUACGAGC : %GC = 53.33
# UCAGCAACUACGUCC : %GC = 53.33
# UCAGCAACUACGUCG : %GC = 53.33
# UCAGCCACAACAAGC : %GC = 53.33
# UCAGCCACAACAUCC : %GC = 53.33
# UCAGCCACAACAUCG : %GC = 53.33
# UCAGCCACAACCAGU : %GC = 53.33
# UCAGCCACAACCUCA : %GC = 53.33
# UCAGCCACAACCUCU : %GC = 53.33
# UCAGCCACAACGAGU : %GC = 53.33
# UCAGCCACAACGUCA : %GC = 53.33
# UCAGCCACAACGUCU : %GC = 53.33
# UCAGCCACAACUAGC : %GC = 53.33
# UCAGCCACAACUUCC : %GC = 53.33
# UCAGCCACAACUUCG : %GC = 53.33
# UCAGCCACCACAAGU : %GC = 53.33
# UCAGCCACCACAUCA : %GC = 53.33
# UCAGCCACCACAUCU : %GC = 53.33
# UCAGCCACCACUAGU : %GC = 53.33
# UCAGCCACCACUUCA : %GC = 53.33
# UCAGCCACCACUUCU : %GC = 53.33
# UCAGCCACGACAAGU : %GC = 53.33
# UCAGCCACGACAUCA : %GC = 53.33
# UCAGCCACGACAUCU : %GC = 53.33
# UCAGCCACGACUAGU : %GC = 53.33
# UCAGCCACGACUUCA : %GC = 53.33
# UCAGCCACGACUUCU : %GC = 53.33
# UCAGCCACUACAAGC : %GC = 53.33
# UCAGCCACUACAUCC : %GC = 53.33
# UCAGCCACUACAUCG : %GC = 53.33
# UCAGCCACUACCAGU : %GC = 53.33
# UCAGCCACUACCUCA : %GC = 53.33
# UCAGCCACUACCUCU : %GC = 53.33
# UCAGCCACUACGAGU : %GC = 53.33
# UCAGCCACUACGUCA : %GC = 53.33
# UCAGCCACUACGUCU : %GC = 53.33
# UCAGCCACUACUAGC : %GC = 53.33
# UCAGCCACUACUUCC : %GC = 53.33
# UCAGCCACUACUUCG : %GC = 53.33
# UCAGCGACAACAAGC : %GC = 53.33
# UCAGCGACAACAUCC : %GC = 53.33
# UCAGCGACAACAUCG : %GC = 53.33
# UCAGCGACAACCAGU : %GC = 53.33
# UCAGCGACAACCUCA : %GC = 53.33
# UCAGCGACAACCUCU : %GC = 53.33
# UCAGCGACAACGAGU : %GC = 53.33
# UCAGCGACAACGUCA : %GC = 53.33
# UCAGCGACAACGUCU : %GC = 53.33
# UCAGCGACAACUAGC : %GC = 53.33
# UCAGCGACAACUUCC : %GC = 53.33
# UCAGCGACAACUUCG : %GC = 53.33
# UCAGCGACCACAAGU : %GC = 53.33
# UCAGCGACCACAUCA : %GC = 53.33
# UCAGCGACCACAUCU : %GC = 53.33
# UCAGCGACCACUAGU : %GC = 53.33
# UCAGCGACCACUUCA : %GC = 53.33
# UCAGCGACCACUUCU : %GC = 53.33
# UCAGCGACGACAAGU : %GC = 53.33
# UCAGCGACGACAUCA : %GC = 53.33
# UCAGCGACGACAUCU : %GC = 53.33
# UCAGCGACGACUAGU : %GC = 53.33
# UCAGCGACGACUUCA : %GC = 53.33
# UCAGCGACGACUUCU : %GC = 53.33
# UCAGCGACUACAAGC : %GC = 53.33
# UCAGCGACUACAUCC : %GC = 53.33
# UCAGCGACUACAUCG : %GC = 53.33
# UCAGCGACUACCAGU : %GC = 53.33
# UCAGCGACUACCUCA : %GC = 53.33
# UCAGCGACUACCUCU : %GC = 53.33
# UCAGCGACUACGAGU : %GC = 53.33
# UCAGCGACUACGUCA : %GC = 53.33
# UCAGCGACUACGUCU : %GC = 53.33
# UCAGCGACUACUAGC : %GC = 53.33
# UCAGCGACUACUUCC : %GC = 53.33
# UCAGCGACUACUUCG : %GC = 53.33
# UCAGCUACAACCAGC : %GC = 53.33
# UCAGCUACAACCUCC : %GC = 53.33
# UCAGCUACAACCUCG : %GC = 53.33
# UCAGCUACAACGAGC : %GC = 53.33
# UCAGCUACAACGUCC : %GC = 53.33
# UCAGCUACAACGUCG : %GC = 53.33
# UCAGCUACCACAAGC : %GC = 53.33
# UCAGCUACCACAUCC : %GC = 53.33
# UCAGCUACCACAUCG : %GC = 53.33
# UCAGCUACCACCAGU : %GC = 53.33
# UCAGCUACCACCUCA : %GC = 53.33
# UCAGCUACCACCUCU : %GC = 53.33
# UCAGCUACCACGAGU : %GC = 53.33
# UCAGCUACCACGUCA : %GC = 53.33
# UCAGCUACCACGUCU : %GC = 53.33
# UCAGCUACCACUAGC : %GC = 53.33
# UCAGCUACCACUUCC : %GC = 53.33
# UCAGCUACCACUUCG : %GC = 53.33
# UCAGCUACGACAAGC : %GC = 53.33
# UCAGCUACGACAUCC : %GC = 53.33
# UCAGCUACGACAUCG : %GC = 53.33
# UCAGCUACGACCAGU : %GC = 53.33
# UCAGCUACGACCUCA : %GC = 53.33
# UCAGCUACGACCUCU : %GC = 53.33
# UCAGCUACGACGAGU : %GC = 53.33
# UCAGCUACGACGUCA : %GC = 53.33
# UCAGCUACGACGUCU : %GC = 53.33
# UCAGCUACGACUAGC : %GC = 53.33
# UCAGCUACGACUUCC : %GC = 53.33
# UCAGCUACGACUUCG : %GC = 53.33
# UCAGCUACUACCAGC : %GC = 53.33
# UCAGCUACUACCUCC : %GC = 53.33
# UCAGCUACUACCUCG : %GC = 53.33
# UCAGCUACUACGAGC : %GC = 53.33
# UCAGCUACUACGUCC : %GC = 53.33
# UCAGCUACUACGUCG : %GC = 53.33
# UCCGCAACAACAAGC : %GC = 53.33
# UCCGCAACAACAUCC : %GC = 53.33
# UCCGCAACAACAUCG : %GC = 53.33
# UCCGCAACAACCAGU : %GC = 53.33
# UCCGCAACAACCUCA : %GC = 53.33
# UCCGCAACAACCUCU : %GC = 53.33
# UCCGCAACAACGAGU : %GC = 53.33
# UCCGCAACAACGUCA : %GC = 53.33
# UCCGCAACAACGUCU : %GC = 53.33
# UCCGCAACAACUAGC : %GC = 53.33
# UCCGCAACAACUUCC : %GC = 53.33
# UCCGCAACAACUUCG : %GC = 53.33
# UCCGCAACCACAAGU : %GC = 53.33
# UCCGCAACCACAUCA : %GC = 53.33
# UCCGCAACCACAUCU : %GC = 53.33
# UCCGCAACCACUAGU : %GC = 53.33
# UCCGCAACCACUUCA : %GC = 53.33
# UCCGCAACCACUUCU : %GC = 53.33
# UCCGCAACGACAAGU : %GC = 53.33
# UCCGCAACGACAUCA : %GC = 53.33
# UCCGCAACGACAUCU : %GC = 53.33
# UCCGCAACGACUAGU : %GC = 53.33
# UCCGCAACGACUUCA : %GC = 53.33
# UCCGCAACGACUUCU : %GC = 53.33
# UCCGCAACUACAAGC : %GC = 53.33
# UCCGCAACUACAUCC : %GC = 53.33
# UCCGCAACUACAUCG : %GC = 53.33
# UCCGCAACUACCAGU : %GC = 53.33
# UCCGCAACUACCUCA : %GC = 53.33
# UCCGCAACUACCUCU : %GC = 53.33
# UCCGCAACUACGAGU : %GC = 53.33
# UCCGCAACUACGUCA : %GC = 53.33
# UCCGCAACUACGUCU : %GC = 53.33
# UCCGCAACUACUAGC : %GC = 53.33
# UCCGCAACUACUUCC : %GC = 53.33
# UCCGCAACUACUUCG : %GC = 53.33
# UCCGCCACAACAAGU : %GC = 53.33
# UCCGCCACAACAUCA : %GC = 53.33
# UCCGCCACAACAUCU : %GC = 53.33
# UCCGCCACAACUAGU : %GC = 53.33
# UCCGCCACAACUUCA : %GC = 53.33
# UCCGCCACAACUUCU : %GC = 53.33
# UCCGCCACUACAAGU : %GC = 53.33
# UCCGCCACUACAUCA : %GC = 53.33
# UCCGCCACUACAUCU : %GC = 53.33
# UCCGCCACUACUAGU : %GC = 53.33
# UCCGCCACUACUUCA : %GC = 53.33
# UCCGCCACUACUUCU : %GC = 53.33
# UCCGCGACAACAAGU : %GC = 53.33
# UCCGCGACAACAUCA : %GC = 53.33
# UCCGCGACAACAUCU : %GC = 53.33
# UCCGCGACAACUAGU : %GC = 53.33
# UCCGCGACAACUUCA : %GC = 53.33
# UCCGCGACAACUUCU : %GC = 53.33
# UCCGCGACUACAAGU : %GC = 53.33
# UCCGCGACUACAUCA : %GC = 53.33
# UCCGCGACUACAUCU : %GC = 53.33
# UCCGCGACUACUAGU : %GC = 53.33
# UCCGCGACUACUUCA : %GC = 53.33
# UCCGCGACUACUUCU : %GC = 53.33
# UCCGCUACAACAAGC : %GC = 53.33
# UCCGCUACAACAUCC : %GC = 53.33
# UCCGCUACAACAUCG : %GC = 53.33
# UCCGCUACAACCAGU : %GC = 53.33
# UCCGCUACAACCUCA : %GC = 53.33
# UCCGCUACAACCUCU : %GC = 53.33
# UCCGCUACAACGAGU : %GC = 53.33
# UCCGCUACAACGUCA : %GC = 53.33
# UCCGCUACAACGUCU : %GC = 53.33
# UCCGCUACAACUAGC : %GC = 53.33
# UCCGCUACAACUUCC : %GC = 53.33
# UCCGCUACAACUUCG : %GC = 53.33
# UCCGCUACCACAAGU : %GC = 53.33
# UCCGCUACCACAUCA : %GC = 53.33
# UCCGCUACCACAUCU : %GC = 53.33
# UCCGCUACCACUAGU : %GC = 53.33
# UCCGCUACCACUUCA : %GC = 53.33
# UCCGCUACCACUUCU : %GC = 53.33
# UCCGCUACGACAAGU : %GC = 53.33
# UCCGCUACGACAUCA : %GC = 53.33
# UCCGCUACGACAUCU : %GC = 53.33
# UCCGCUACGACUAGU : %GC = 53.33
# UCCGCUACGACUUCA : %GC = 53.33
# UCCGCUACGACUUCU : %GC = 53.33
# UCCGCUACUACAAGC : %GC = 53.33
# UCCGCUACUACAUCC : %GC = 53.33
# UCCGCUACUACAUCG : %GC = 53.33
# UCCGCUACUACCAGU : %GC = 53.33
# UCCGCUACUACCUCA : %GC = 53.33
# UCCGCUACUACCUCU : %GC = 53.33
# UCCGCUACUACGAGU : %GC = 53.33
# UCCGCUACUACGUCA : %GC = 53.33
# UCCGCUACUACGUCU : %GC = 53.33
# UCCGCUACUACUAGC : %GC = 53.33
# UCCGCUACUACUUCC : %GC = 53.33
# UCCGCUACUACUUCG : %GC = 53.33
# UCGGCAACAACAAGC : %GC = 53.33
# UCGGCAACAACAUCC : %GC = 53.33
# UCGGCAACAACAUCG : %GC = 53.33
# UCGGCAACAACCAGU : %GC = 53.33
# UCGGCAACAACCUCA : %GC = 53.33
# UCGGCAACAACCUCU : %GC = 53.33
# UCGGCAACAACGAGU : %GC = 53.33
# UCGGCAACAACGUCA : %GC = 53.33
# UCGGCAACAACGUCU : %GC = 53.33
# UCGGCAACAACUAGC : %GC = 53.33
# UCGGCAACAACUUCC : %GC = 53.33
# UCGGCAACAACUUCG : %GC = 53.33
# UCGGCAACCACAAGU : %GC = 53.33
# UCGGCAACCACAUCA : %GC = 53.33
# UCGGCAACCACAUCU : %GC = 53.33
# UCGGCAACCACUAGU : %GC = 53.33
# UCGGCAACCACUUCA : %GC = 53.33
# UCGGCAACCACUUCU : %GC = 53.33
# UCGGCAACGACAAGU : %GC = 53.33
# UCGGCAACGACAUCA : %GC = 53.33
# UCGGCAACGACAUCU : %GC = 53.33
# UCGGCAACGACUAGU : %GC = 53.33
# UCGGCAACGACUUCA : %GC = 53.33
# UCGGCAACGACUUCU : %GC = 53.33
# UCGGCAACUACAAGC : %GC = 53.33
# UCGGCAACUACAUCC : %GC = 53.33
# UCGGCAACUACAUCG : %GC = 53.33
# UCGGCAACUACCAGU : %GC = 53.33
# UCGGCAACUACCUCA : %GC = 53.33
# UCGGCAACUACCUCU : %GC = 53.33
# UCGGCAACUACGAGU : %GC = 53.33
# UCGGCAACUACGUCA : %GC = 53.33
# UCGGCAACUACGUCU : %GC = 53.33
# UCGGCAACUACUAGC : %GC = 53.33
# UCGGCAACUACUUCC : %GC = 53.33
# UCGGCAACUACUUCG : %GC = 53.33
# UCGGCCACAACAAGU : %GC = 53.33
# UCGGCCACAACAUCA : %GC = 53.33
# UCGGCCACAACAUCU : %GC = 53.33
# UCGGCCACAACUAGU : %GC = 53.33
# UCGGCCACAACUUCA : %GC = 53.33
# UCGGCCACAACUUCU : %GC = 53.33
# UCGGCCACUACAAGU : %GC = 53.33
# UCGGCCACUACAUCA : %GC = 53.33
# UCGGCCACUACAUCU : %GC = 53.33
# UCGGCCACUACUAGU : %GC = 53.33
# UCGGCCACUACUUCA : %GC = 53.33
# UCGGCCACUACUUCU : %GC = 53.33
# UCGGCGACAACAAGU : %GC = 53.33
# UCGGCGACAACAUCA : %GC = 53.33
# UCGGCGACAACAUCU : %GC = 53.33
# UCGGCGACAACUAGU : %GC = 53.33
# UCGGCGACAACUUCA : %GC = 53.33
# UCGGCGACAACUUCU : %GC = 53.33
# UCGGCGACUACAAGU : %GC = 53.33
# UCGGCGACUACAUCA : %GC = 53.33
# UCGGCGACUACAUCU : %GC = 53.33
# UCGGCGACUACUAGU : %GC = 53.33
# UCGGCGACUACUUCA : %GC = 53.33
# UCGGCGACUACUUCU : %GC = 53.33
# UCGGCUACAACAAGC : %GC = 53.33
# UCGGCUACAACAUCC : %GC = 53.33
# UCGGCUACAACAUCG : %GC = 53.33
# UCGGCUACAACCAGU : %GC = 53.33
# UCGGCUACAACCUCA : %GC = 53.33
# UCGGCUACAACCUCU : %GC = 53.33
# UCGGCUACAACGAGU : %GC = 53.33
# UCGGCUACAACGUCA : %GC = 53.33
# UCGGCUACAACGUCU : %GC = 53.33
# UCGGCUACAACUAGC : %GC = 53.33
# UCGGCUACAACUUCC : %GC = 53.33
# UCGGCUACAACUUCG : %GC = 53.33
# UCGGCUACCACAAGU : %GC = 53.33
# UCGGCUACCACAUCA : %GC = 53.33
# UCGGCUACCACAUCU : %GC = 53.33
# UCGGCUACCACUAGU : %GC = 53.33
# UCGGCUACCACUUCA : %GC = 53.33
# UCGGCUACCACUUCU : %GC = 53.33
# UCGGCUACGACAAGU : %GC = 53.33
# UCGGCUACGACAUCA : %GC = 53.33
# UCGGCUACGACAUCU : %GC = 53.33
# UCGGCUACGACUAGU : %GC = 53.33
# UCGGCUACGACUUCA : %GC = 53.33
# UCGGCUACGACUUCU : %GC = 53.33
# UCGGCUACUACAAGC : %GC = 53.33
# UCGGCUACUACAUCC : %GC = 53.33
# UCGGCUACUACAUCG : %GC = 53.33
# UCGGCUACUACCAGU : %GC = 53.33
# UCGGCUACUACCUCA : %GC = 53.33
# UCGGCUACUACCUCU : %GC = 53.33
# UCGGCUACUACGAGU : %GC = 53.33
# UCGGCUACUACGUCA : %GC = 53.33
# UCGGCUACUACGUCU : %GC = 53.33
# UCGGCUACUACUAGC : %GC = 53.33
# UCGGCUACUACUUCC : %GC = 53.33
# UCGGCUACUACUUCG : %GC = 53.33
# UCUGCAACAACCAGC : %GC = 53.33
# UCUGCAACAACCUCC : %GC = 53.33
# UCUGCAACAACCUCG : %GC = 53.33
# UCUGCAACAACGAGC : %GC = 53.33
# UCUGCAACAACGUCC : %GC = 53.33
# UCUGCAACAACGUCG : %GC = 53.33
# UCUGCAACCACAAGC : %GC = 53.33
# UCUGCAACCACAUCC : %GC = 53.33
# UCUGCAACCACAUCG : %GC = 53.33
# UCUGCAACCACCAGU : %GC = 53.33
# UCUGCAACCACCUCA : %GC = 53.33
# UCUGCAACCACCUCU : %GC = 53.33
# UCUGCAACCACGAGU : %GC = 53.33
# UCUGCAACCACGUCA : %GC = 53.33
# UCUGCAACCACGUCU : %GC = 53.33
# UCUGCAACCACUAGC : %GC = 53.33
# UCUGCAACCACUUCC : %GC = 53.33
# UCUGCAACCACUUCG : %GC = 53.33
# UCUGCAACGACAAGC : %GC = 53.33
# UCUGCAACGACAUCC : %GC = 53.33
# UCUGCAACGACAUCG : %GC = 53.33
# UCUGCAACGACCAGU : %GC = 53.33
# UCUGCAACGACCUCA : %GC = 53.33
# UCUGCAACGACCUCU : %GC = 53.33
# UCUGCAACGACGAGU : %GC = 53.33
# UCUGCAACGACGUCA : %GC = 53.33
# UCUGCAACGACGUCU : %GC = 53.33
# UCUGCAACGACUAGC : %GC = 53.33
# UCUGCAACGACUUCC : %GC = 53.33
# UCUGCAACGACUUCG : %GC = 53.33
# UCUGCAACUACCAGC : %GC = 53.33
# UCUGCAACUACCUCC : %GC = 53.33
# UCUGCAACUACCUCG : %GC = 53.33
# UCUGCAACUACGAGC : %GC = 53.33
# UCUGCAACUACGUCC : %GC = 53.33
# UCUGCAACUACGUCG : %GC = 53.33
# UCUGCCACAACAAGC : %GC = 53.33
# UCUGCCACAACAUCC : %GC = 53.33
# UCUGCCACAACAUCG : %GC = 53.33
# UCUGCCACAACCAGU : %GC = 53.33
# UCUGCCACAACCUCA : %GC = 53.33
# UCUGCCACAACCUCU : %GC = 53.33
# UCUGCCACAACGAGU : %GC = 53.33
# UCUGCCACAACGUCA : %GC = 53.33
# UCUGCCACAACGUCU : %GC = 53.33
# UCUGCCACAACUAGC : %GC = 53.33
# UCUGCCACAACUUCC : %GC = 53.33
# UCUGCCACAACUUCG : %GC = 53.33
# UCUGCCACCACAAGU : %GC = 53.33
# UCUGCCACCACAUCA : %GC = 53.33
# UCUGCCACCACAUCU : %GC = 53.33
# UCUGCCACCACUAGU : %GC = 53.33
# UCUGCCACCACUUCA : %GC = 53.33
# UCUGCCACCACUUCU : %GC = 53.33
# UCUGCCACGACAAGU : %GC = 53.33
# UCUGCCACGACAUCA : %GC = 53.33
# UCUGCCACGACAUCU : %GC = 53.33
# UCUGCCACGACUAGU : %GC = 53.33
# UCUGCCACGACUUCA : %GC = 53.33
# UCUGCCACGACUUCU : %GC = 53.33
# UCUGCCACUACAAGC : %GC = 53.33
# UCUGCCACUACAUCC : %GC = 53.33
# UCUGCCACUACAUCG : %GC = 53.33
# UCUGCCACUACCAGU : %GC = 53.33
# UCUGCCACUACCUCA : %GC = 53.33
# UCUGCCACUACCUCU : %GC = 53.33
# UCUGCCACUACGAGU : %GC = 53.33
# UCUGCCACUACGUCA : %GC = 53.33
# UCUGCCACUACGUCU : %GC = 53.33
# UCUGCCACUACUAGC : %GC = 53.33
# UCUGCCACUACUUCC : %GC = 53.33
# UCUGCCACUACUUCG : %GC = 53.33
# UCUGCGACAACAAGC : %GC = 53.33
# UCUGCGACAACAUCC : %GC = 53.33
# UCUGCGACAACAUCG : %GC = 53.33
# UCUGCGACAACCAGU : %GC = 53.33
# UCUGCGACAACCUCA : %GC = 53.33
# UCUGCGACAACCUCU : %GC = 53.33
# UCUGCGACAACGAGU : %GC = 53.33
# UCUGCGACAACGUCA : %GC = 53.33
# UCUGCGACAACGUCU : %GC = 53.33
# UCUGCGACAACUAGC : %GC = 53.33
# UCUGCGACAACUUCC : %GC = 53.33
# UCUGCGACAACUUCG : %GC = 53.33
# UCUGCGACCACAAGU : %GC = 53.33
# UCUGCGACCACAUCA : %GC = 53.33
# UCUGCGACCACAUCU : %GC = 53.33
# UCUGCGACCACUAGU : %GC = 53.33
# UCUGCGACCACUUCA : %GC = 53.33
# UCUGCGACCACUUCU : %GC = 53.33
# UCUGCGACGACAAGU : %GC = 53.33
# UCUGCGACGACAUCA : %GC = 53.33
# UCUGCGACGACAUCU : %GC = 53.33
# UCUGCGACGACUAGU : %GC = 53.33
# UCUGCGACGACUUCA : %GC = 53.33
# UCUGCGACGACUUCU : %GC = 53.33
# UCUGCGACUACAAGC : %GC = 53.33
# UCUGCGACUACAUCC : %GC = 53.33
# UCUGCGACUACAUCG : %GC = 53.33
# UCUGCGACUACCAGU : %GC = 53.33
# UCUGCGACUACCUCA : %GC = 53.33
# UCUGCGACUACCUCU : %GC = 53.33
# UCUGCGACUACGAGU : %GC = 53.33
# UCUGCGACUACGUCA : %GC = 53.33
# UCUGCGACUACGUCU : %GC = 53.33
# UCUGCGACUACUAGC : %GC = 53.33
# UCUGCGACUACUUCC : %GC = 53.33
# UCUGCGACUACUUCG : %GC = 53.33
# UCUGCUACAACCAGC : %GC = 53.33
# UCUGCUACAACCUCC : %GC = 53.33
# UCUGCUACAACCUCG : %GC = 53.33
# UCUGCUACAACGAGC : %GC = 53.33
# UCUGCUACAACGUCC : %GC = 53.33
# UCUGCUACAACGUCG : %GC = 53.33
# UCUGCUACCACAAGC : %GC = 53.33
# UCUGCUACCACAUCC : %GC = 53.33
# UCUGCUACCACAUCG : %GC = 53.33
# UCUGCUACCACCAGU : %GC = 53.33
# UCUGCUACCACCUCA : %GC = 53.33
# UCUGCUACCACCUCU : %GC = 53.33
# UCUGCUACCACGAGU : %GC = 53.33
# UCUGCUACCACGUCA : %GC = 53.33
# UCUGCUACCACGUCU : %GC = 53.33
# UCUGCUACCACUAGC : %GC = 53.33
# UCUGCUACCACUUCC : %GC = 53.33
# UCUGCUACCACUUCG : %GC = 53.33
# UCUGCUACGACAAGC : %GC = 53.33
# UCUGCUACGACAUCC : %GC = 53.33
# UCUGCUACGACAUCG : %GC = 53.33
# UCUGCUACGACCAGU : %GC = 53.33
# UCUGCUACGACCUCA : %GC = 53.33
# UCUGCUACGACCUCU : %GC = 53.33
# UCUGCUACGACGAGU : %GC = 53.33
# UCUGCUACGACGUCA : %GC = 53.33
# UCUGCUACGACGUCU : %GC = 53.33
# UCUGCUACGACUAGC : %GC = 53.33
# UCUGCUACGACUUCC : %GC = 53.33
# UCUGCUACGACUUCG : %GC = 53.33
# UCUGCUACUACCAGC : %GC = 53.33
# UCUGCUACUACCUCC : %GC = 53.33
# UCUGCUACUACCUCG : %GC = 53.33
# UCUGCUACUACGAGC : %GC = 53.33
# UCUGCUACUACGUCC : %GC = 53.33
# UCUGCUACUACGUCG : %GC = 53.33
# AGCGCAACAACCAGC : %GC = 60.0
# AGCGCAACAACCUCC : %GC = 60.0
# AGCGCAACAACCUCG : %GC = 60.0
# AGCGCAACAACGAGC : %GC = 60.0
# AGCGCAACAACGUCC : %GC = 60.0
# AGCGCAACAACGUCG : %GC = 60.0
# AGCGCAACCACAAGC : %GC = 60.0
# AGCGCAACCACAUCC : %GC = 60.0
# AGCGCAACCACAUCG : %GC = 60.0
# AGCGCAACCACCAGU : %GC = 60.0
# AGCGCAACCACCUCA : %GC = 60.0
# AGCGCAACCACCUCU : %GC = 60.0
# AGCGCAACCACGAGU : %GC = 60.0
# AGCGCAACCACGUCA : %GC = 60.0
# AGCGCAACCACGUCU : %GC = 60.0
# AGCGCAACCACUAGC : %GC = 60.0
# AGCGCAACCACUUCC : %GC = 60.0
# AGCGCAACCACUUCG : %GC = 60.0
# AGCGCAACGACAAGC : %GC = 60.0
# AGCGCAACGACAUCC : %GC = 60.0
# AGCGCAACGACAUCG : %GC = 60.0
# AGCGCAACGACCAGU : %GC = 60.0
# AGCGCAACGACCUCA : %GC = 60.0
# AGCGCAACGACCUCU : %GC = 60.0
# AGCGCAACGACGAGU : %GC = 60.0
# AGCGCAACGACGUCA : %GC = 60.0
# AGCGCAACGACGUCU : %GC = 60.0
# AGCGCAACGACUAGC : %GC = 60.0
# AGCGCAACGACUUCC : %GC = 60.0
# AGCGCAACGACUUCG : %GC = 60.0
# AGCGCAACUACCAGC : %GC = 60.0
# AGCGCAACUACCUCC : %GC = 60.0
# AGCGCAACUACCUCG : %GC = 60.0
# AGCGCAACUACGAGC : %GC = 60.0
# AGCGCAACUACGUCC : %GC = 60.0
# AGCGCAACUACGUCG : %GC = 60.0
# AGCGCCACAACAAGC : %GC = 60.0
# AGCGCCACAACAUCC : %GC = 60.0
# AGCGCCACAACAUCG : %GC = 60.0
# AGCGCCACAACCAGU : %GC = 60.0
# AGCGCCACAACCUCA : %GC = 60.0
# AGCGCCACAACCUCU : %GC = 60.0
# AGCGCCACAACGAGU : %GC = 60.0
# AGCGCCACAACGUCA : %GC = 60.0
# AGCGCCACAACGUCU : %GC = 60.0
# AGCGCCACAACUAGC : %GC = 60.0
# AGCGCCACAACUUCC : %GC = 60.0
# AGCGCCACAACUUCG : %GC = 60.0
# AGCGCCACCACAAGU : %GC = 60.0
# AGCGCCACCACAUCA : %GC = 60.0
# AGCGCCACCACAUCU : %GC = 60.0
# AGCGCCACCACUAGU : %GC = 60.0
# AGCGCCACCACUUCA : %GC = 60.0
# AGCGCCACCACUUCU : %GC = 60.0
# AGCGCCACGACAAGU : %GC = 60.0
# AGCGCCACGACAUCA : %GC = 60.0
# AGCGCCACGACAUCU : %GC = 60.0
# AGCGCCACGACUAGU : %GC = 60.0
# AGCGCCACGACUUCA : %GC = 60.0
# AGCGCCACGACUUCU : %GC = 60.0
# AGCGCCACUACAAGC : %GC = 60.0
# AGCGCCACUACAUCC : %GC = 60.0
# AGCGCCACUACAUCG : %GC = 60.0
# AGCGCCACUACCAGU : %GC = 60.0
# AGCGCCACUACCUCA : %GC = 60.0
# AGCGCCACUACCUCU : %GC = 60.0
# AGCGCCACUACGAGU : %GC = 60.0
# AGCGCCACUACGUCA : %GC = 60.0
# AGCGCCACUACGUCU : %GC = 60.0
# AGCGCCACUACUAGC : %GC = 60.0
# AGCGCCACUACUUCC : %GC = 60.0
# AGCGCCACUACUUCG : %GC = 60.0
# AGCGCGACAACAAGC : %GC = 60.0
# AGCGCGACAACAUCC : %GC = 60.0
# AGCGCGACAACAUCG : %GC = 60.0
# AGCGCGACAACCAGU : %GC = 60.0
# AGCGCGACAACCUCA : %GC = 60.0
# AGCGCGACAACCUCU : %GC = 60.0
# AGCGCGACAACGAGU : %GC = 60.0
# AGCGCGACAACGUCA : %GC = 60.0
# AGCGCGACAACGUCU : %GC = 60.0
# AGCGCGACAACUAGC : %GC = 60.0
# AGCGCGACAACUUCC : %GC = 60.0
# AGCGCGACAACUUCG : %GC = 60.0
# AGCGCGACCACAAGU : %GC = 60.0
# AGCGCGACCACAUCA : %GC = 60.0
# AGCGCGACCACAUCU : %GC = 60.0
# AGCGCGACCACUAGU : %GC = 60.0
# AGCGCGACCACUUCA : %GC = 60.0
# AGCGCGACCACUUCU : %GC = 60.0
# AGCGCGACGACAAGU : %GC = 60.0
# AGCGCGACGACAUCA : %GC = 60.0
# AGCGCGACGACAUCU : %GC = 60.0
# AGCGCGACGACUAGU : %GC = 60.0
# AGCGCGACGACUUCA : %GC = 60.0
# AGCGCGACGACUUCU : %GC = 60.0
# AGCGCGACUACAAGC : %GC = 60.0
# AGCGCGACUACAUCC : %GC = 60.0
# AGCGCGACUACAUCG : %GC = 60.0
# AGCGCGACUACCAGU : %GC = 60.0
# AGCGCGACUACCUCA : %GC = 60.0
# AGCGCGACUACCUCU : %GC = 60.0
# AGCGCGACUACGAGU : %GC = 60.0
# AGCGCGACUACGUCA : %GC = 60.0
# AGCGCGACUACGUCU : %GC = 60.0
# AGCGCGACUACUAGC : %GC = 60.0
# AGCGCGACUACUUCC : %GC = 60.0
# AGCGCGACUACUUCG : %GC = 60.0
# AGCGCUACAACCAGC : %GC = 60.0
# AGCGCUACAACCUCC : %GC = 60.0
# AGCGCUACAACCUCG : %GC = 60.0
# AGCGCUACAACGAGC : %GC = 60.0
# AGCGCUACAACGUCC : %GC = 60.0
# AGCGCUACAACGUCG : %GC = 60.0
# AGCGCUACCACAAGC : %GC = 60.0
# AGCGCUACCACAUCC : %GC = 60.0
# AGCGCUACCACAUCG : %GC = 60.0
# AGCGCUACCACCAGU : %GC = 60.0
# AGCGCUACCACCUCA : %GC = 60.0
# AGCGCUACCACCUCU : %GC = 60.0
# AGCGCUACCACGAGU : %GC = 60.0
# AGCGCUACCACGUCA : %GC = 60.0
# AGCGCUACCACGUCU : %GC = 60.0
# AGCGCUACCACUAGC : %GC = 60.0
# AGCGCUACCACUUCC : %GC = 60.0
# AGCGCUACCACUUCG : %GC = 60.0
# AGCGCUACGACAAGC : %GC = 60.0
# AGCGCUACGACAUCC : %GC = 60.0
# AGCGCUACGACAUCG : %GC = 60.0
# AGCGCUACGACCAGU : %GC = 60.0
# AGCGCUACGACCUCA : %GC = 60.0
# AGCGCUACGACCUCU : %GC = 60.0
# AGCGCUACGACGAGU : %GC = 60.0
# AGCGCUACGACGUCA : %GC = 60.0
# AGCGCUACGACGUCU : %GC = 60.0
# AGCGCUACGACUAGC : %GC = 60.0
# AGCGCUACGACUUCC : %GC = 60.0
# AGCGCUACGACUUCG : %GC = 60.0
# AGCGCUACUACCAGC : %GC = 60.0
# AGCGCUACUACCUCC : %GC = 60.0
# AGCGCUACUACCUCG : %GC = 60.0
# AGCGCUACUACGAGC : %GC = 60.0
# AGCGCUACUACGUCC : %GC = 60.0
# AGCGCUACUACGUCG : %GC = 60.0
# AGUGCAACCACCAGC : %GC = 60.0
# AGUGCAACCACCUCC : %GC = 60.0
# AGUGCAACCACCUCG : %GC = 60.0
# AGUGCAACCACGAGC : %GC = 60.0
# AGUGCAACCACGUCC : %GC = 60.0
# AGUGCAACCACGUCG : %GC = 60.0
# AGUGCAACGACCAGC : %GC = 60.0
# AGUGCAACGACCUCC : %GC = 60.0
# AGUGCAACGACCUCG : %GC = 60.0
# AGUGCAACGACGAGC : %GC = 60.0
# AGUGCAACGACGUCC : %GC = 60.0
# AGUGCAACGACGUCG : %GC = 60.0
# AGUGCCACAACCAGC : %GC = 60.0
# AGUGCCACAACCUCC : %GC = 60.0
# AGUGCCACAACCUCG : %GC = 60.0
# AGUGCCACAACGAGC : %GC = 60.0
# AGUGCCACAACGUCC : %GC = 60.0
# AGUGCCACAACGUCG : %GC = 60.0
# AGUGCCACCACAAGC : %GC = 60.0
# AGUGCCACCACAUCC : %GC = 60.0
# AGUGCCACCACAUCG : %GC = 60.0
# AGUGCCACCACCAGU : %GC = 60.0
# AGUGCCACCACCUCA : %GC = 60.0
# AGUGCCACCACCUCU : %GC = 60.0
# AGUGCCACCACGAGU : %GC = 60.0
# AGUGCCACCACGUCA : %GC = 60.0
# AGUGCCACCACGUCU : %GC = 60.0
# AGUGCCACCACUAGC : %GC = 60.0
# AGUGCCACCACUUCC : %GC = 60.0
# AGUGCCACCACUUCG : %GC = 60.0
# AGUGCCACGACAAGC : %GC = 60.0
# AGUGCCACGACAUCC : %GC = 60.0
# AGUGCCACGACAUCG : %GC = 60.0
# AGUGCCACGACCAGU : %GC = 60.0
# AGUGCCACGACCUCA : %GC = 60.0
# AGUGCCACGACCUCU : %GC = 60.0
# AGUGCCACGACGAGU : %GC = 60.0
# AGUGCCACGACGUCA : %GC = 60.0
# AGUGCCACGACGUCU : %GC = 60.0
# AGUGCCACGACUAGC : %GC = 60.0
# AGUGCCACGACUUCC : %GC = 60.0
# AGUGCCACGACUUCG : %GC = 60.0
# AGUGCCACUACCAGC : %GC = 60.0
# AGUGCCACUACCUCC : %GC = 60.0
# AGUGCCACUACCUCG : %GC = 60.0
# AGUGCCACUACGAGC : %GC = 60.0
# AGUGCCACUACGUCC : %GC = 60.0
# AGUGCCACUACGUCG : %GC = 60.0
# AGUGCGACAACCAGC : %GC = 60.0
# AGUGCGACAACCUCC : %GC = 60.0
# AGUGCGACAACCUCG : %GC = 60.0
# AGUGCGACAACGAGC : %GC = 60.0
# AGUGCGACAACGUCC : %GC = 60.0
# AGUGCGACAACGUCG : %GC = 60.0
# AGUGCGACCACAAGC : %GC = 60.0
# AGUGCGACCACAUCC : %GC = 60.0
# AGUGCGACCACAUCG : %GC = 60.0
# AGUGCGACCACCAGU : %GC = 60.0
# AGUGCGACCACCUCA : %GC = 60.0
# AGUGCGACCACCUCU : %GC = 60.0
# AGUGCGACCACGAGU : %GC = 60.0
# AGUGCGACCACGUCA : %GC = 60.0
# AGUGCGACCACGUCU : %GC = 60.0
# AGUGCGACCACUAGC : %GC = 60.0
# AGUGCGACCACUUCC : %GC = 60.0
# AGUGCGACCACUUCG : %GC = 60.0
# AGUGCGACGACAAGC : %GC = 60.0
# AGUGCGACGACAUCC : %GC = 60.0
# AGUGCGACGACAUCG : %GC = 60.0
# AGUGCGACGACCAGU : %GC = 60.0
# AGUGCGACGACCUCA : %GC = 60.0
# AGUGCGACGACCUCU : %GC = 60.0
# AGUGCGACGACGAGU : %GC = 60.0
# AGUGCGACGACGUCA : %GC = 60.0
# AGUGCGACGACGUCU : %GC = 60.0
# AGUGCGACGACUAGC : %GC = 60.0
# AGUGCGACGACUUCC : %GC = 60.0
# AGUGCGACGACUUCG : %GC = 60.0
# AGUGCGACUACCAGC : %GC = 60.0
# AGUGCGACUACCUCC : %GC = 60.0
# AGUGCGACUACCUCG : %GC = 60.0
# AGUGCGACUACGAGC : %GC = 60.0
# AGUGCGACUACGUCC : %GC = 60.0
# AGUGCGACUACGUCG : %GC = 60.0
# AGUGCUACCACCAGC : %GC = 60.0
# AGUGCUACCACCUCC : %GC = 60.0
# AGUGCUACCACCUCG : %GC = 60.0
# AGUGCUACCACGAGC : %GC = 60.0
# AGUGCUACCACGUCC : %GC = 60.0
# AGUGCUACCACGUCG : %GC = 60.0
# AGUGCUACGACCAGC : %GC = 60.0
# AGUGCUACGACCUCC : %GC = 60.0
# AGUGCUACGACCUCG : %GC = 60.0
# AGUGCUACGACGAGC : %GC = 60.0
# AGUGCUACGACGUCC : %GC = 60.0
# AGUGCUACGACGUCG : %GC = 60.0
# UCAGCAACCACCAGC : %GC = 60.0
# UCAGCAACCACCUCC : %GC = 60.0
# UCAGCAACCACCUCG : %GC = 60.0
# UCAGCAACCACGAGC : %GC = 60.0
# UCAGCAACCACGUCC : %GC = 60.0
# UCAGCAACCACGUCG : %GC = 60.0
# UCAGCAACGACCAGC : %GC = 60.0
# UCAGCAACGACCUCC : %GC = 60.0
# UCAGCAACGACCUCG : %GC = 60.0
# UCAGCAACGACGAGC : %GC = 60.0
# UCAGCAACGACGUCC : %GC = 60.0
# UCAGCAACGACGUCG : %GC = 60.0
# UCAGCCACAACCAGC : %GC = 60.0
# UCAGCCACAACCUCC : %GC = 60.0
# UCAGCCACAACCUCG : %GC = 60.0
# UCAGCCACAACGAGC : %GC = 60.0
# UCAGCCACAACGUCC : %GC = 60.0
# UCAGCCACAACGUCG : %GC = 60.0
# UCAGCCACCACAAGC : %GC = 60.0
# UCAGCCACCACAUCC : %GC = 60.0
# UCAGCCACCACAUCG : %GC = 60.0
# UCAGCCACCACCAGU : %GC = 60.0
# UCAGCCACCACCUCA : %GC = 60.0
# UCAGCCACCACCUCU : %GC = 60.0
# UCAGCCACCACGAGU : %GC = 60.0
# UCAGCCACCACGUCA : %GC = 60.0
# UCAGCCACCACGUCU : %GC = 60.0
# UCAGCCACCACUAGC : %GC = 60.0
# UCAGCCACCACUUCC : %GC = 60.0
# UCAGCCACCACUUCG : %GC = 60.0
# UCAGCCACGACAAGC : %GC = 60.0
# UCAGCCACGACAUCC : %GC = 60.0
# UCAGCCACGACAUCG : %GC = 60.0
# UCAGCCACGACCAGU : %GC = 60.0
# UCAGCCACGACCUCA : %GC = 60.0
# UCAGCCACGACCUCU : %GC = 60.0
# UCAGCCACGACGAGU : %GC = 60.0
# UCAGCCACGACGUCA : %GC = 60.0
# UCAGCCACGACGUCU : %GC = 60.0
# UCAGCCACGACUAGC : %GC = 60.0
# UCAGCCACGACUUCC : %GC = 60.0
# UCAGCCACGACUUCG : %GC = 60.0
# UCAGCCACUACCAGC : %GC = 60.0
# UCAGCCACUACCUCC : %GC = 60.0
# UCAGCCACUACCUCG : %GC = 60.0
# UCAGCCACUACGAGC : %GC = 60.0
# UCAGCCACUACGUCC : %GC = 60.0
# UCAGCCACUACGUCG : %GC = 60.0
# UCAGCGACAACCAGC : %GC = 60.0
# UCAGCGACAACCUCC : %GC = 60.0
# UCAGCGACAACCUCG : %GC = 60.0
# UCAGCGACAACGAGC : %GC = 60.0
# UCAGCGACAACGUCC : %GC = 60.0
# UCAGCGACAACGUCG : %GC = 60.0
# UCAGCGACCACAAGC : %GC = 60.0
# UCAGCGACCACAUCC : %GC = 60.0
# UCAGCGACCACAUCG : %GC = 60.0
# UCAGCGACCACCAGU : %GC = 60.0
# UCAGCGACCACCUCA : %GC = 60.0
# UCAGCGACCACCUCU : %GC = 60.0
# UCAGCGACCACGAGU : %GC = 60.0
# UCAGCGACCACGUCA : %GC = 60.0
# UCAGCGACCACGUCU : %GC = 60.0
# UCAGCGACCACUAGC : %GC = 60.0
# UCAGCGACCACUUCC : %GC = 60.0
# UCAGCGACCACUUCG : %GC = 60.0
# UCAGCGACGACAAGC : %GC = 60.0
# UCAGCGACGACAUCC : %GC = 60.0
# UCAGCGACGACAUCG : %GC = 60.0
# UCAGCGACGACCAGU : %GC = 60.0
# UCAGCGACGACCUCA : %GC = 60.0
# UCAGCGACGACCUCU : %GC = 60.0
# UCAGCGACGACGAGU : %GC = 60.0
# UCAGCGACGACGUCA : %GC = 60.0
# UCAGCGACGACGUCU : %GC = 60.0
# UCAGCGACGACUAGC : %GC = 60.0
# UCAGCGACGACUUCC : %GC = 60.0
# UCAGCGACGACUUCG : %GC = 60.0
# UCAGCGACUACCAGC : %GC = 60.0
# UCAGCGACUACCUCC : %GC = 60.0
# UCAGCGACUACCUCG : %GC = 60.0
# UCAGCGACUACGAGC : %GC = 60.0
# UCAGCGACUACGUCC : %GC = 60.0
# UCAGCGACUACGUCG : %GC = 60.0
# UCAGCUACCACCAGC : %GC = 60.0
# UCAGCUACCACCUCC : %GC = 60.0
# UCAGCUACCACCUCG : %GC = 60.0
# UCAGCUACCACGAGC : %GC = 60.0
# UCAGCUACCACGUCC : %GC = 60.0
# UCAGCUACCACGUCG : %GC = 60.0
# UCAGCUACGACCAGC : %GC = 60.0
# UCAGCUACGACCUCC : %GC = 60.0
# UCAGCUACGACCUCG : %GC = 60.0
# UCAGCUACGACGAGC : %GC = 60.0
# UCAGCUACGACGUCC : %GC = 60.0
# UCAGCUACGACGUCG : %GC = 60.0
# UCCGCAACAACCAGC : %GC = 60.0
# UCCGCAACAACCUCC : %GC = 60.0
# UCCGCAACAACCUCG : %GC = 60.0
# UCCGCAACAACGAGC : %GC = 60.0
# UCCGCAACAACGUCC : %GC = 60.0
# UCCGCAACAACGUCG : %GC = 60.0
# UCCGCAACCACAAGC : %GC = 60.0
# UCCGCAACCACAUCC : %GC = 60.0
# UCCGCAACCACAUCG : %GC = 60.0
# UCCGCAACCACCAGU : %GC = 60.0
# UCCGCAACCACCUCA : %GC = 60.0
# UCCGCAACCACCUCU : %GC = 60.0
# UCCGCAACCACGAGU : %GC = 60.0
# UCCGCAACCACGUCA : %GC = 60.0
# UCCGCAACCACGUCU : %GC = 60.0
# UCCGCAACCACUAGC : %GC = 60.0
# UCCGCAACCACUUCC : %GC = 60.0
# UCCGCAACCACUUCG : %GC = 60.0
# UCCGCAACGACAAGC : %GC = 60.0
# UCCGCAACGACAUCC : %GC = 60.0
# UCCGCAACGACAUCG : %GC = 60.0
# UCCGCAACGACCAGU : %GC = 60.0
# UCCGCAACGACCUCA : %GC = 60.0
# UCCGCAACGACCUCU : %GC = 60.0
# UCCGCAACGACGAGU : %GC = 60.0
# UCCGCAACGACGUCA : %GC = 60.0
# UCCGCAACGACGUCU : %GC = 60.0
# UCCGCAACGACUAGC : %GC = 60.0
# UCCGCAACGACUUCC : %GC = 60.0
# UCCGCAACGACUUCG : %GC = 60.0
# UCCGCAACUACCAGC : %GC = 60.0
# UCCGCAACUACCUCC : %GC = 60.0
# UCCGCAACUACCUCG : %GC = 60.0
# UCCGCAACUACGAGC : %GC = 60.0
# UCCGCAACUACGUCC : %GC = 60.0
# UCCGCAACUACGUCG : %GC = 60.0
# UCCGCCACAACAAGC : %GC = 60.0
# UCCGCCACAACAUCC : %GC = 60.0
# UCCGCCACAACAUCG : %GC = 60.0
# UCCGCCACAACCAGU : %GC = 60.0
# UCCGCCACAACCUCA : %GC = 60.0
# UCCGCCACAACCUCU : %GC = 60.0
# UCCGCCACAACGAGU : %GC = 60.0
# UCCGCCACAACGUCA : %GC = 60.0
# UCCGCCACAACGUCU : %GC = 60.0
# UCCGCCACAACUAGC : %GC = 60.0
# UCCGCCACAACUUCC : %GC = 60.0
# UCCGCCACAACUUCG : %GC = 60.0
# UCCGCCACCACAAGU : %GC = 60.0
# UCCGCCACCACAUCA : %GC = 60.0
# UCCGCCACCACAUCU : %GC = 60.0
# UCCGCCACCACUAGU : %GC = 60.0
# UCCGCCACCACUUCA : %GC = 60.0
# UCCGCCACCACUUCU : %GC = 60.0
# UCCGCCACGACAAGU : %GC = 60.0
# UCCGCCACGACAUCA : %GC = 60.0
# UCCGCCACGACAUCU : %GC = 60.0
# UCCGCCACGACUAGU : %GC = 60.0
# UCCGCCACGACUUCA : %GC = 60.0
# UCCGCCACGACUUCU : %GC = 60.0
# UCCGCCACUACAAGC : %GC = 60.0
# UCCGCCACUACAUCC : %GC = 60.0
# UCCGCCACUACAUCG : %GC = 60.0
# UCCGCCACUACCAGU : %GC = 60.0
# UCCGCCACUACCUCA : %GC = 60.0
# UCCGCCACUACCUCU : %GC = 60.0
# UCCGCCACUACGAGU : %GC = 60.0
# UCCGCCACUACGUCA : %GC = 60.0
# UCCGCCACUACGUCU : %GC = 60.0
# UCCGCCACUACUAGC : %GC = 60.0
# UCCGCCACUACUUCC : %GC = 60.0
# UCCGCCACUACUUCG : %GC = 60.0
# UCCGCGACAACAAGC : %GC = 60.0
# UCCGCGACAACAUCC : %GC = 60.0
# UCCGCGACAACAUCG : %GC = 60.0
# UCCGCGACAACCAGU : %GC = 60.0
# UCCGCGACAACCUCA : %GC = 60.0
# UCCGCGACAACCUCU : %GC = 60.0
# UCCGCGACAACGAGU : %GC = 60.0
# UCCGCGACAACGUCA : %GC = 60.0
# UCCGCGACAACGUCU : %GC = 60.0
# UCCGCGACAACUAGC : %GC = 60.0
# UCCGCGACAACUUCC : %GC = 60.0
# UCCGCGACAACUUCG : %GC = 60.0
# UCCGCGACCACAAGU : %GC = 60.0
# UCCGCGACCACAUCA : %GC = 60.0
# UCCGCGACCACAUCU : %GC = 60.0
# UCCGCGACCACUAGU : %GC = 60.0
# UCCGCGACCACUUCA : %GC = 60.0
# UCCGCGACCACUUCU : %GC = 60.0
# UCCGCGACGACAAGU : %GC = 60.0
# UCCGCGACGACAUCA : %GC = 60.0
# UCCGCGACGACAUCU : %GC = 60.0
# UCCGCGACGACUAGU : %GC = 60.0
# UCCGCGACGACUUCA : %GC = 60.0
# UCCGCGACGACUUCU : %GC = 60.0
# UCCGCGACUACAAGC : %GC = 60.0
# UCCGCGACUACAUCC : %GC = 60.0
# UCCGCGACUACAUCG : %GC = 60.0
# UCCGCGACUACCAGU : %GC = 60.0
# UCCGCGACUACCUCA : %GC = 60.0
# UCCGCGACUACCUCU : %GC = 60.0
# UCCGCGACUACGAGU : %GC = 60.0
# UCCGCGACUACGUCA : %GC = 60.0
# UCCGCGACUACGUCU : %GC = 60.0
# UCCGCGACUACUAGC : %GC = 60.0
# UCCGCGACUACUUCC : %GC = 60.0
# UCCGCGACUACUUCG : %GC = 60.0
# UCCGCUACAACCAGC : %GC = 60.0
# UCCGCUACAACCUCC : %GC = 60.0
# UCCGCUACAACCUCG : %GC = 60.0
# UCCGCUACAACGAGC : %GC = 60.0
# UCCGCUACAACGUCC : %GC = 60.0
# UCCGCUACAACGUCG : %GC = 60.0
# UCCGCUACCACAAGC : %GC = 60.0
# UCCGCUACCACAUCC : %GC = 60.0
# UCCGCUACCACAUCG : %GC = 60.0
# UCCGCUACCACCAGU : %GC = 60.0
# UCCGCUACCACCUCA : %GC = 60.0
# UCCGCUACCACCUCU : %GC = 60.0
# UCCGCUACCACGAGU : %GC = 60.0
# UCCGCUACCACGUCA : %GC = 60.0
# UCCGCUACCACGUCU : %GC = 60.0
# UCCGCUACCACUAGC : %GC = 60.0
# ...
# AGUGCGACGACAUCU : %GC = 53.33
# AGUGCGACGACUAGU : %GC = 53.33
# AGUGCGACGACUUCA : %GC = 53.33
# AGUGCGACGACUUCU : %GC = 53.33
# AGUGCGACUACAAGC : %GC = 53.33
# AGUGCGACUACAUCC : %GC = 53.33
# AGUGCGACUACAUCG : %GC = 53.33
# AGUGCGACUACCAGU : %GC = 53.33
# AGUGCGACUACCUCA : %GC = 53.33
# AGUGCGACUACCUCU : %GC = 53.33
# AGUGCGACUACGAGU : %GC = 53.33
# AGUGCGACUACGUCA : %GC = 53.33
# AGUGCGACUACGUCU : %GC = 53.33
# AGUGCGACUACUAGC : %GC = 53.33
# AGUGCGACUACUUCC : %GC = 53.33
# AGUGCGACUACUUCG : %GC = 53.33
# AGUGCUACAACCAGC : %GC = 53.33
# AGUGCUACAACCUCC : %GC = 53.33
# AGUGCUACAACCUCG : %GC = 53.33
# AGUGCUACAACGAGC : %GC = 53.33
# AGUGCUACAACGUCC : %GC = 53.33
# AGUGCUACAACGUCG : %GC = 53.33
# AGUGCUACCACAAGC : %GC = 53.33
# AGUGCUACCACAUCC : %GC = 53.33
# AGUGCUACCACAUCG : %GC = 53.33
# AGUGCUACCACCAGU : %GC = 53.33
# AGUGCUACCACCUCA : %GC = 53.33
# AGUGCUACCACCUCU : %GC = 53.33
# AGUGCUACCACGAGU : %GC = 53.33
# AGUGCUACCACGUCA : %GC = 53.33
# AGUGCUACCACGUCU : %GC = 53.33
# AGUGCUACCACUAGC : %GC = 53.33
# AGUGCUACCACUUCC : %GC = 53.33
# AGUGCUACCACUUCG : %GC = 53.33
# AGUGCUACGACAAGC : %GC = 53.33
# AGUGCUACGACAUCC : %GC = 53.33
# AGUGCUACGACAUCG : %GC = 53.33
# AGUGCUACGACCAGU : %GC = 53.33
# AGUGCUACGACCUCA : %GC = 53.33
# AGUGCUACGACCUCU : %GC = 53.33
# AGUGCUACGACGAGU : %GC = 53.33
# AGUGCUACGACGUCA : %GC = 53.33
# AGUGCUACGACGUCU : %GC = 53.33
# AGUGCUACGACUAGC : %GC = 53.33
# AGUGCUACGACUUCC : %GC = 53.33
# AGUGCUACGACUUCG : %GC = 53.33
# AGUGCUACUACCAGC : %GC = 53.33
# AGUGCUACUACCUCC : %GC = 53.33
# AGUGCUACUACCUCG : %GC = 53.33
# AGUGCUACUACGAGC : %GC = 53.33
# AGUGCUACUACGUCC : %GC = 53.33
# AGUGCUACUACGUCG : %GC = 53.33
# UCAGCAACAACCAGC : %GC = 53.33
# UCAGCAACAACCUCC : %GC = 53.33
# UCAGCAACAACCUCG : %GC = 53.33
# UCAGCAACAACGAGC : %GC = 53.33
# UCAGCAACAACGUCC : %GC = 53.33
# UCAGCAACAACGUCG : %GC = 53.33
# UCAGCAACCACAAGC : %GC = 53.33
# UCAGCAACCACAUCC : %GC = 53.33
# UCAGCAACCACAUCG : %GC = 53.33
# UCAGCAACCACCAGU : %GC = 53.33
# UCAGCAACCACCUCA : %GC = 53.33
# UCAGCAACCACCUCU : %GC = 53.33
# UCAGCAACCACGAGU : %GC = 53.33
# UCAGCAACCACGUCA : %GC = 53.33
# UCAGCAACCACGUCU : %GC = 53.33
# UCAGCAACCACUAGC : %GC = 53.33
# UCAGCAACCACUUCC : %GC = 53.33
# UCAGCAACCACUUCG : %GC = 53.33
# UCAGCAACGACAAGC : %GC = 53.33
# UCAGCAACGACAUCC : %GC = 53.33
# UCAGCAACGACAUCG : %GC = 53.33
# UCAGCAACGACCAGU : %GC = 53.33
# UCAGCAACGACCUCA : %GC = 53.33
# UCAGCAACGACCUCU : %GC = 53.33
# UCAGCAACGACGAGU : %GC = 53.33
# UCAGCAACGACGUCA : %GC = 53.33
# UCAGCAACGACGUCU : %GC = 53.33
# UCAGCAACGACUAGC : %GC = 53.33
# UCAGCAACGACUUCC : %GC = 53.33
# UCAGCAACGACUUCG : %GC = 53.33
# UCAGCAACUACCAGC : %GC = 53.33
# UCAGCAACUACCUCC : %GC = 53.33
# UCAGCAACUACCUCG : %GC = 53.33
# UCAGCAACUACGAGC : %GC = 53.33
# UCAGCAACUACGUCC : %GC = 53.33
# UCAGCAACUACGUCG : %GC = 53.33
# UCAGCCACAACAAGC : %GC = 53.33
# UCAGCCACAACAUCC : %GC = 53.33
# UCAGCCACAACAUCG : %GC = 53.33
# UCAGCCACAACCAGU : %GC = 53.33
# UCAGCCACAACCUCA : %GC = 53.33
# UCAGCCACAACCUCU : %GC = 53.33
# UCAGCCACAACGAGU : %GC = 53.33
# UCAGCCACAACGUCA : %GC = 53.33
# UCAGCCACAACGUCU : %GC = 53.33
# UCAGCCACAACUAGC : %GC = 53.33
# UCAGCCACAACUUCC : %GC = 53.33
# UCAGCCACAACUUCG : %GC = 53.33
# UCAGCCACCACAAGU : %GC = 53.33
# UCAGCCACCACAUCA : %GC = 53.33
# UCAGCCACCACAUCU : %GC = 53.33
# UCAGCCACCACUAGU : %GC = 53.33
# UCAGCCACCACUUCA : %GC = 53.33
# UCAGCCACCACUUCU : %GC = 53.33
# UCAGCCACGACAAGU : %GC = 53.33
# UCAGCCACGACAUCA : %GC = 53.33
# UCAGCCACGACAUCU : %GC = 53.33
# UCAGCCACGACUAGU : %GC = 53.33
# UCAGCCACGACUUCA : %GC = 53.33
# UCAGCCACGACUUCU : %GC = 53.33
# UCAGCCACUACAAGC : %GC = 53.33
# UCAGCCACUACAUCC : %GC = 53.33
# UCAGCCACUACAUCG : %GC = 53.33
# UCAGCCACUACCAGU : %GC = 53.33
# UCAGCCACUACCUCA : %GC = 53.33
# UCAGCCACUACCUCU : %GC = 53.33
# UCAGCCACUACGAGU : %GC = 53.33
# UCAGCCACUACGUCA : %GC = 53.33
# UCAGCCACUACGUCU : %GC = 53.33
# UCAGCCACUACUAGC : %GC = 53.33
# UCAGCCACUACUUCC : %GC = 53.33
# UCAGCCACUACUUCG : %GC = 53.33
# UCAGCGACAACAAGC : %GC = 53.33
# UCAGCGACAACAUCC : %GC = 53.33
# UCAGCGACAACAUCG : %GC = 53.33
# UCAGCGACAACCAGU : %GC = 53.33
# UCAGCGACAACCUCA : %GC = 53.33
# UCAGCGACAACCUCU : %GC = 53.33
# UCAGCGACAACGAGU : %GC = 53.33
# UCAGCGACAACGUCA : %GC = 53.33
# UCAGCGACAACGUCU : %GC = 53.33
# UCAGCGACAACUAGC : %GC = 53.33
# UCAGCGACAACUUCC : %GC = 53.33
# UCAGCGACAACUUCG : %GC = 53.33
# UCAGCGACCACAAGU : %GC = 53.33
# UCAGCGACCACAUCA : %GC = 53.33
# UCAGCGACCACAUCU : %GC = 53.33
# UCAGCGACCACUAGU : %GC = 53.33
# UCAGCGACCACUUCA : %GC = 53.33
# UCAGCGACCACUUCU : %GC = 53.33
# UCAGCGACGACAAGU : %GC = 53.33
# UCAGCGACGACAUCA : %GC = 53.33
# UCAGCGACGACAUCU : %GC = 53.33
# UCAGCGACGACUAGU : %GC = 53.33
# UCAGCGACGACUUCA : %GC = 53.33
# UCAGCGACGACUUCU : %GC = 53.33
# UCAGCGACUACAAGC : %GC = 53.33
# UCAGCGACUACAUCC : %GC = 53.33
# UCAGCGACUACAUCG : %GC = 53.33
# UCAGCGACUACCAGU : %GC = 53.33
# UCAGCGACUACCUCA : %GC = 53.33
# UCAGCGACUACCUCU : %GC = 53.33
# UCAGCGACUACGAGU : %GC = 53.33
# UCAGCGACUACGUCA : %GC = 53.33
# UCAGCGACUACGUCU : %GC = 53.33
# UCAGCGACUACUAGC : %GC = 53.33
# UCAGCGACUACUUCC : %GC = 53.33
# UCAGCGACUACUUCG : %GC = 53.33
# UCAGCUACAACCAGC : %GC = 53.33
# UCAGCUACAACCUCC : %GC = 53.33
# UCAGCUACAACCUCG : %GC = 53.33
# UCAGCUACAACGAGC : %GC = 53.33
# UCAGCUACAACGUCC : %GC = 53.33
# UCAGCUACAACGUCG : %GC = 53.33
# UCAGCUACCACAAGC : %GC = 53.33
# UCAGCUACCACAUCC : %GC = 53.33
# UCAGCUACCACAUCG : %GC = 53.33
# UCAGCUACCACCAGU : %GC = 53.33
# UCAGCUACCACCUCA : %GC = 53.33
# UCAGCUACCACCUCU : %GC = 53.33
# UCAGCUACCACGAGU : %GC = 53.33
# UCAGCUACCACGUCA : %GC = 53.33
# UCAGCUACCACGUCU : %GC = 53.33
# UCAGCUACCACUAGC : %GC = 53.33
# UCAGCUACCACUUCC : %GC = 53.33
# UCAGCUACCACUUCG : %GC = 53.33
# UCAGCUACGACAAGC : %GC = 53.33
# UCAGCUACGACAUCC : %GC = 53.33
# UCAGCUACGACAUCG : %GC = 53.33
# UCAGCUACGACCAGU : %GC = 53.33
# UCAGCUACGACCUCA : %GC = 53.33
# UCAGCUACGACCUCU : %GC = 53.33
# UCAGCUACGACGAGU : %GC = 53.33
# UCAGCUACGACGUCA : %GC = 53.33
# UCAGCUACGACGUCU : %GC = 53.33
# UCAGCUACGACUAGC : %GC = 53.33
# UCAGCUACGACUUCC : %GC = 53.33
# UCAGCUACGACUUCG : %GC = 53.33
# UCAGCUACUACCAGC : %GC = 53.33
# UCAGCUACUACCUCC : %GC = 53.33
# UCAGCUACUACCUCG : %GC = 53.33
# UCAGCUACUACGAGC : %GC = 53.33
# UCAGCUACUACGUCC : %GC = 53.33
# UCAGCUACUACGUCG : %GC = 53.33
# UCCGCAACAACAAGC : %GC = 53.33
# UCCGCAACAACAUCC : %GC = 53.33
# UCCGCAACAACAUCG : %GC = 53.33
# UCCGCAACAACCAGU : %GC = 53.33
# UCCGCAACAACCUCA : %GC = 53.33
# UCCGCAACAACCUCU : %GC = 53.33
# UCCGCAACAACGAGU : %GC = 53.33
# UCCGCAACAACGUCA : %GC = 53.33
# UCCGCAACAACGUCU : %GC = 53.33
# UCCGCAACAACUAGC : %GC = 53.33
# UCCGCAACAACUUCC : %GC = 53.33
# UCCGCAACAACUUCG : %GC = 53.33
# UCCGCAACCACAAGU : %GC = 53.33
# UCCGCAACCACAUCA : %GC = 53.33
# UCCGCAACCACAUCU : %GC = 53.33
# UCCGCAACCACUAGU : %GC = 53.33
# UCCGCAACCACUUCA : %GC = 53.33
# UCCGCAACCACUUCU : %GC = 53.33
# UCCGCAACGACAAGU : %GC = 53.33
# UCCGCAACGACAUCA : %GC = 53.33
# UCCGCAACGACAUCU : %GC = 53.33
# UCCGCAACGACUAGU : %GC = 53.33
# UCCGCAACGACUUCA : %GC = 53.33
# UCCGCAACGACUUCU : %GC = 53.33
# UCCGCAACUACAAGC : %GC = 53.33
# UCCGCAACUACAUCC : %GC = 53.33
# UCCGCAACUACAUCG : %GC = 53.33
# UCCGCAACUACCAGU : %GC = 53.33
# UCCGCAACUACCUCA : %GC = 53.33
# UCCGCAACUACCUCU : %GC = 53.33
# UCCGCAACUACGAGU : %GC = 53.33
# UCCGCAACUACGUCA : %GC = 53.33
# UCCGCAACUACGUCU : %GC = 53.33
# UCCGCAACUACUAGC : %GC = 53.33
# UCCGCAACUACUUCC : %GC = 53.33
# UCCGCAACUACUUCG : %GC = 53.33
# UCCGCCACAACAAGU : %GC = 53.33
# UCCGCCACAACAUCA : %GC = 53.33
# UCCGCCACAACAUCU : %GC = 53.33
# UCCGCCACAACUAGU : %GC = 53.33
# UCCGCCACAACUUCA : %GC = 53.33
# UCCGCCACAACUUCU : %GC = 53.33
# UCCGCCACUACAAGU : %GC = 53.33
# UCCGCCACUACAUCA : %GC = 53.33
# UCCGCCACUACAUCU : %GC = 53.33
# UCCGCCACUACUAGU : %GC = 53.33
# UCCGCCACUACUUCA : %GC = 53.33
# UCCGCCACUACUUCU : %GC = 53.33
# UCCGCGACAACAAGU : %GC = 53.33
# UCCGCGACAACAUCA : %GC = 53.33
# UCCGCGACAACAUCU : %GC = 53.33
# UCCGCGACAACUAGU : %GC = 53.33
# UCCGCGACAACUUCA : %GC = 53.33
# UCCGCGACAACUUCU : %GC = 53.33
# UCCGCGACUACAAGU : %GC = 53.33
# UCCGCGACUACAUCA : %GC = 53.33
# UCCGCGACUACAUCU : %GC = 53.33
# UCCGCGACUACUAGU : %GC = 53.33
# UCCGCGACUACUUCA : %GC = 53.33
# UCCGCGACUACUUCU : %GC = 53.33
# UCCGCUACAACAAGC : %GC = 53.33
# UCCGCUACAACAUCC : %GC = 53.33
# UCCGCUACAACAUCG : %GC = 53.33
# UCCGCUACAACCAGU : %GC = 53.33
# UCCGCUACAACCUCA : %GC = 53.33
# UCCGCUACAACCUCU : %GC = 53.33
# UCCGCUACAACGAGU : %GC = 53.33
# UCCGCUACAACGUCA : %GC = 53.33
# UCCGCUACAACGUCU : %GC = 53.33
# UCCGCUACAACUAGC : %GC = 53.33
# UCCGCUACAACUUCC : %GC = 53.33
# UCCGCUACAACUUCG : %GC = 53.33
# UCCGCUACCACAAGU : %GC = 53.33
# UCCGCUACCACAUCA : %GC = 53.33
# UCCGCUACCACAUCU : %GC = 53.33
# UCCGCUACCACUAGU : %GC = 53.33
# UCCGCUACCACUUCA : %GC = 53.33
# UCCGCUACCACUUCU : %GC = 53.33
# UCCGCUACGACAAGU : %GC = 53.33
# UCCGCUACGACAUCA : %GC = 53.33
# UCCGCUACGACAUCU : %GC = 53.33
# UCCGCUACGACUAGU : %GC = 53.33
# UCCGCUACGACUUCA : %GC = 53.33
# UCCGCUACGACUUCU : %GC = 53.33
# UCCGCUACUACAAGC : %GC = 53.33
# UCCGCUACUACAUCC : %GC = 53.33
# UCCGCUACUACAUCG : %GC = 53.33
# UCCGCUACUACCAGU : %GC = 53.33
# UCCGCUACUACCUCA : %GC = 53.33
# UCCGCUACUACCUCU : %GC = 53.33
# UCCGCUACUACGAGU : %GC = 53.33
# UCCGCUACUACGUCA : %GC = 53.33
# UCCGCUACUACGUCU : %GC = 53.33
# UCCGCUACUACUAGC : %GC = 53.33
# UCCGCUACUACUUCC : %GC = 53.33
# UCCGCUACUACUUCG : %GC = 53.33
# UCGGCAACAACAAGC : %GC = 53.33
# UCGGCAACAACAUCC : %GC = 53.33
# UCGGCAACAACAUCG : %GC = 53.33
# UCGGCAACAACCAGU : %GC = 53.33
# UCGGCAACAACCUCA : %GC = 53.33
# UCGGCAACAACCUCU : %GC = 53.33
# UCGGCAACAACGAGU : %GC = 53.33
# UCGGCAACAACGUCA : %GC = 53.33
# UCGGCAACAACGUCU : %GC = 53.33
# UCGGCAACAACUAGC : %GC = 53.33
# UCGGCAACAACUUCC : %GC = 53.33
# UCGGCAACAACUUCG : %GC = 53.33
# UCGGCAACCACAAGU : %GC = 53.33
# UCGGCAACCACAUCA : %GC = 53.33
# UCGGCAACCACAUCU : %GC = 53.33
# UCGGCAACCACUAGU : %GC = 53.33
# UCGGCAACCACUUCA : %GC = 53.33
# UCGGCAACCACUUCU : %GC = 53.33
# UCGGCAACGACAAGU : %GC = 53.33
# UCGGCAACGACAUCA : %GC = 53.33
# UCGGCAACGACAUCU : %GC = 53.33
# UCGGCAACGACUAGU : %GC = 53.33
# UCGGCAACGACUUCA : %GC = 53.33
# UCGGCAACGACUUCU : %GC = 53.33
# UCGGCAACUACAAGC : %GC = 53.33
# UCGGCAACUACAUCC : %GC = 53.33
# UCGGCAACUACAUCG : %GC = 53.33
# UCGGCAACUACCAGU : %GC = 53.33
# UCGGCAACUACCUCA : %GC = 53.33
# UCGGCAACUACCUCU : %GC = 53.33
# UCGGCAACUACGAGU : %GC = 53.33
# UCGGCAACUACGUCA : %GC = 53.33
# UCGGCAACUACGUCU : %GC = 53.33
# UCGGCAACUACUAGC : %GC = 53.33
# UCGGCAACUACUUCC : %GC = 53.33
# UCGGCAACUACUUCG : %GC = 53.33
# UCGGCCACAACAAGU : %GC = 53.33
# UCGGCCACAACAUCA : %GC = 53.33
# UCGGCCACAACAUCU : %GC = 53.33
# UCGGCCACAACUAGU : %GC = 53.33
# UCGGCCACAACUUCA : %GC = 53.33
# UCGGCCACAACUUCU : %GC = 53.33
# UCGGCCACUACAAGU : %GC = 53.33
# UCGGCCACUACAUCA : %GC = 53.33
# UCGGCCACUACAUCU : %GC = 53.33
# UCGGCCACUACUAGU : %GC = 53.33
# UCGGCCACUACUUCA : %GC = 53.33
# UCGGCCACUACUUCU : %GC = 53.33
# UCGGCGACAACAAGU : %GC = 53.33
# UCGGCGACAACAUCA : %GC = 53.33
# UCGGCGACAACAUCU : %GC = 53.33
# UCGGCGACAACUAGU : %GC = 53.33
# UCGGCGACAACUUCA : %GC = 53.33
# UCGGCGACAACUUCU : %GC = 53.33
# UCGGCGACUACAAGU : %GC = 53.33
# UCGGCGACUACAUCA : %GC = 53.33
# UCGGCGACUACAUCU : %GC = 53.33
# UCGGCGACUACUAGU : %GC = 53.33
# UCGGCGACUACUUCA : %GC = 53.33
# UCGGCGACUACUUCU : %GC = 53.33
# UCGGCUACAACAAGC : %GC = 53.33
# UCGGCUACAACAUCC : %GC = 53.33
# UCGGCUACAACAUCG : %GC = 53.33
# UCGGCUACAACCAGU : %GC = 53.33
# UCGGCUACAACCUCA : %GC = 53.33
# UCGGCUACAACCUCU : %GC = 53.33
# UCGGCUACAACGAGU : %GC = 53.33
# UCGGCUACAACGUCA : %GC = 53.33
# UCGGCUACAACGUCU : %GC = 53.33
# UCGGCUACAACUAGC : %GC = 53.33
# UCGGCUACAACUUCC : %GC = 53.33
# UCGGCUACAACUUCG : %GC = 53.33
# UCGGCUACCACAAGU : %GC = 53.33
# UCGGCUACCACAUCA : %GC = 53.33
# UCGGCUACCACAUCU : %GC = 53.33
# UCGGCUACCACUAGU : %GC = 53.33
# UCGGCUACCACUUCA : %GC = 53.33
# UCGGCUACCACUUCU : %GC = 53.33
# UCGGCUACGACAAGU : %GC = 53.33
# UCGGCUACGACAUCA : %GC = 53.33
# UCGGCUACGACAUCU : %GC = 53.33
# UCGGCUACGACUAGU : %GC = 53.33
# UCGGCUACGACUUCA : %GC = 53.33
# UCGGCUACGACUUCU : %GC = 53.33
# UCGGCUACUACAAGC : %GC = 53.33
# UCGGCUACUACAUCC : %GC = 53.33
# UCGGCUACUACAUCG : %GC = 53.33
# UCGGCUACUACCAGU : %GC = 53.33
# UCGGCUACUACCUCA : %GC = 53.33
# UCGGCUACUACCUCU : %GC = 53.33
# UCGGCUACUACGAGU : %GC = 53.33
# UCGGCUACUACGUCA : %GC = 53.33
# UCGGCUACUACGUCU : %GC = 53.33
# UCGGCUACUACUAGC : %GC = 53.33
# UCGGCUACUACUUCC : %GC = 53.33
# UCGGCUACUACUUCG : %GC = 53.33
# UCUGCAACAACCAGC : %GC = 53.33
# UCUGCAACAACCUCC : %GC = 53.33
# UCUGCAACAACCUCG : %GC = 53.33
# UCUGCAACAACGAGC : %GC = 53.33
# UCUGCAACAACGUCC : %GC = 53.33
# UCUGCAACAACGUCG : %GC = 53.33
# UCUGCAACCACAAGC : %GC = 53.33
# UCUGCAACCACAUCC : %GC = 53.33
# UCUGCAACCACAUCG : %GC = 53.33
# UCUGCAACCACCAGU : %GC = 53.33
# UCUGCAACCACCUCA : %GC = 53.33
# UCUGCAACCACCUCU : %GC = 53.33
# UCUGCAACCACGAGU : %GC = 53.33
# UCUGCAACCACGUCA : %GC = 53.33
# UCUGCAACCACGUCU : %GC = 53.33
# UCUGCAACCACUAGC : %GC = 53.33
# UCUGCAACCACUUCC : %GC = 53.33
# UCUGCAACCACUUCG : %GC = 53.33
# UCUGCAACGACAAGC : %GC = 53.33
# UCUGCAACGACAUCC : %GC = 53.33
# UCUGCAACGACAUCG : %GC = 53.33
# UCUGCAACGACCAGU : %GC = 53.33
# UCUGCAACGACCUCA : %GC = 53.33
# UCUGCAACGACCUCU : %GC = 53.33
# UCUGCAACGACGAGU : %GC = 53.33
# UCUGCAACGACGUCA : %GC = 53.33
# UCUGCAACGACGUCU : %GC = 53.33
# UCUGCAACGACUAGC : %GC = 53.33
# UCUGCAACGACUUCC : %GC = 53.33
# UCUGCAACGACUUCG : %GC = 53.33
# UCUGCAACUACCAGC : %GC = 53.33
# UCUGCAACUACCUCC : %GC = 53.33
# UCUGCAACUACCUCG : %GC = 53.33
# UCUGCAACUACGAGC : %GC = 53.33
# UCUGCAACUACGUCC : %GC = 53.33
# UCUGCAACUACGUCG : %GC = 53.33
# UCUGCCACAACAAGC : %GC = 53.33
# UCUGCCACAACAUCC : %GC = 53.33
# UCUGCCACAACAUCG : %GC = 53.33
# UCUGCCACAACCAGU : %GC = 53.33
# UCUGCCACAACCUCA : %GC = 53.33
# UCUGCCACAACCUCU : %GC = 53.33
# UCUGCCACAACGAGU : %GC = 53.33
# UCUGCCACAACGUCA : %GC = 53.33
# UCUGCCACAACGUCU : %GC = 53.33
# UCUGCCACAACUAGC : %GC = 53.33
# UCUGCCACAACUUCC : %GC = 53.33
# UCUGCCACAACUUCG : %GC = 53.33
# UCUGCCACCACAAGU : %GC = 53.33
# UCUGCCACCACAUCA : %GC = 53.33
# UCUGCCACCACAUCU : %GC = 53.33
# UCUGCCACCACUAGU : %GC = 53.33
# UCUGCCACCACUUCA : %GC = 53.33
# UCUGCCACCACUUCU : %GC = 53.33
# UCUGCCACGACAAGU : %GC = 53.33
# UCUGCCACGACAUCA : %GC = 53.33
# UCUGCCACGACAUCU : %GC = 53.33
# UCUGCCACGACUAGU : %GC = 53.33
# UCUGCCACGACUUCA : %GC = 53.33
# UCUGCCACGACUUCU : %GC = 53.33
# UCUGCCACUACAAGC : %GC = 53.33
# UCUGCCACUACAUCC : %GC = 53.33
# UCUGCCACUACAUCG : %GC = 53.33
# UCUGCCACUACCAGU : %GC = 53.33
# UCUGCCACUACCUCA : %GC = 53.33
# UCUGCCACUACCUCU : %GC = 53.33
# UCUGCCACUACGAGU : %GC = 53.33
# UCUGCCACUACGUCA : %GC = 53.33
# UCUGCCACUACGUCU : %GC = 53.33
# UCUGCCACUACUAGC : %GC = 53.33
# UCUGCCACUACUUCC : %GC = 53.33
# UCUGCCACUACUUCG : %GC = 53.33
# UCUGCGACAACAAGC : %GC = 53.33
# UCUGCGACAACAUCC : %GC = 53.33
# UCUGCGACAACAUCG : %GC = 53.33
# UCUGCGACAACCAGU : %GC = 53.33
# UCUGCGACAACCUCA : %GC = 53.33
# UCUGCGACAACCUCU : %GC = 53.33
# UCUGCGACAACGAGU : %GC = 53.33
# UCUGCGACAACGUCA : %GC = 53.33
# UCUGCGACAACGUCU : %GC = 53.33
# UCUGCGACAACUAGC : %GC = 53.33
# UCUGCGACAACUUCC : %GC = 53.33
# UCUGCGACAACUUCG : %GC = 53.33
# UCUGCGACCACAAGU : %GC = 53.33
# UCUGCGACCACAUCA : %GC = 53.33
# UCUGCGACCACAUCU : %GC = 53.33
# UCUGCGACCACUAGU : %GC = 53.33
# UCUGCGACCACUUCA : %GC = 53.33
# UCUGCGACCACUUCU : %GC = 53.33
# UCUGCGACGACAAGU : %GC = 53.33
# UCUGCGACGACAUCA : %GC = 53.33
# UCUGCGACGACAUCU : %GC = 53.33
# UCUGCGACGACUAGU : %GC = 53.33
# UCUGCGACGACUUCA : %GC = 53.33
# UCUGCGACGACUUCU : %GC = 53.33
# UCUGCGACUACAAGC : %GC = 53.33
# UCUGCGACUACAUCC : %GC = 53.33
# UCUGCGACUACAUCG : %GC = 53.33
# UCUGCGACUACCAGU : %GC = 53.33
# UCUGCGACUACCUCA : %GC = 53.33
# UCUGCGACUACCUCU : %GC = 53.33
# UCUGCGACUACGAGU : %GC = 53.33
# UCUGCGACUACGUCA : %GC = 53.33
# UCUGCGACUACGUCU : %GC = 53.33
# UCUGCGACUACUAGC : %GC = 53.33
# UCUGCGACUACUUCC : %GC = 53.33
# UCUGCGACUACUUCG : %GC = 53.33
# UCUGCUACAACCAGC : %GC = 53.33
# UCUGCUACAACCUCC : %GC = 53.33
# UCUGCUACAACCUCG : %GC = 53.33
# UCUGCUACAACGAGC : %GC = 53.33
# UCUGCUACAACGUCC : %GC = 53.33
# UCUGCUACAACGUCG : %GC = 53.33
# UCUGCUACCACAAGC : %GC = 53.33
# UCUGCUACCACAUCC : %GC = 53.33
# UCUGCUACCACAUCG : %GC = 53.33
# UCUGCUACCACCAGU : %GC = 53.33
# UCUGCUACCACCUCA : %GC = 53.33
# UCUGCUACCACCUCU : %GC = 53.33
# UCUGCUACCACGAGU : %GC = 53.33
# UCUGCUACCACGUCA : %GC = 53.33
# UCUGCUACCACGUCU : %GC = 53.33
# UCUGCUACCACUAGC : %GC = 53.33
# UCUGCUACCACUUCC : %GC = 53.33
# UCUGCUACCACUUCG : %GC = 53.33
# UCUGCUACGACAAGC : %GC = 53.33
# UCUGCUACGACAUCC : %GC = 53.33
# UCUGCUACGACAUCG : %GC = 53.33
# UCUGCUACGACCAGU : %GC = 53.33
# UCUGCUACGACCUCA : %GC = 53.33
# UCUGCUACGACCUCU : %GC = 53.33
# UCUGCUACGACGAGU : %GC = 53.33
# UCUGCUACGACGUCA : %GC = 53.33
# UCUGCUACGACGUCU : %GC = 53.33
# UCUGCUACGACUAGC : %GC = 53.33
# UCUGCUACGACUUCC : %GC = 53.33
# UCUGCUACGACUUCG : %GC = 53.33
# UCUGCUACUACCAGC : %GC = 53.33
# UCUGCUACUACCUCC : %GC = 53.33
# UCUGCUACUACCUCG : %GC = 53.33
# UCUGCUACUACGAGC : %GC = 53.33
# UCUGCUACUACGUCC : %GC = 53.33
# UCUGCUACUACGUCG : %GC = 53.33
#
# ( Run Time:  0:00:01.210790 )
